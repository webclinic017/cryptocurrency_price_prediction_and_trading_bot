# %% [markdown]
# ## Preparation

# %%
import time
import json
import hmac
import hashlib
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from urllib.parse import urljoin, urlencode

# %%
type_dict = {
    'open_time': 'int64',
    'open': 'float64',
    'high': 'float64',
    'low': 'float64',
    'close': 'float64',
    'volume': 'float64',
    'quote_asset_volume': 'float64',
    'number_of_trades': 'int32',
    'taker_buy_base_asset_volume': 'float64',
    'taker_buy_quote_asset_volume': 'float64'
}

last_time = 1655892000000
start_time = 1513695600000

# %%
first_token = "BTC"
second_token = "BUSD"
perp_token_pair = first_token + second_token
spot_token_pair = first_token + second_token
time_interval = "1h"

save_future_data_path = "../data/raw/future/raw_future_binance_%s_%s_%s.csv" % (first_token.lower(), second_token.lower(), time_interval)
save_spot_data_path = "../data/raw/spot/raw_spot_binance_%s_%s_%s.csv" % (first_token.lower(), second_token.lower(), time_interval)

# %% [markdown]
# ## Perpetual contract data

# %%
API_KEY = "Z0GPxBlUJVbpllNE7F5ywtt7LAFOO7ATNYijsDgNUQezWWYvDliiUOjMeMEYRBI8"
SECRET_KEY = "QHOlbP5fpwWO8DxyWT5LH7OkJ5fED7GSgqZxs91LSqKreUXs1KESBN1SkvFzvLdM"
BASE_URL = 'https://fapi.binance.com'

headers = {
    'X-MBX-APIKEY': API_KEY
}

PATH = '/fapi/v1/klines'

future_data = []

for endTime in range(last_time, start_time, -500*3600000):
    startTime = endTime - 499*3600000
        
    params = {
        'symbol': perp_token_pair,
        'contractType': 'PERPETUAL',
        'interval': '1h',
        'startTime': startTime,
        'endTime': endTime
    }        
    
    temp = []
    
    url = urljoin(BASE_URL, PATH)
    r = requests.get(url, headers=headers, params=params)
    
    if r.status_code == 200:
        temp = list(r.json())
        future_data = temp + future_data

# %%
len(future_data)
# Out:
# 12628

# %%
perp_df = pd.DataFrame(future_data)
perp_df.columns = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
perp_df.drop(columns=['close_time', 'ignore'], inplace=True)
perp_df = perp_df.astype(type_dict)
perp_df.drop_duplicates(inplace=True)

if (perp_df["open_time"] - perp_df["open_time"].shift(1) != 3600000.0).sum() == 1:
    print("Data is consistent, the dataframe is saved succesfully!")
    perp_df.to_csv(save_future_data_path)
else:
    print("Data not consistent")
# Out:
# Data is consistent, the dataframe is saved succesfully!

# %%
steps = 1400 # Timestamp steps to be shown in the ploting figure

sns.set()

fig = plt.figure(figsize=(16,9), dpi=90)
ax = fig.add_subplot(111)

ax.plot(perp_df["close"][:perp_df.shape[0]])

ax.set_title(perp_token_pair, fontsize=20)

ax.set_xticks(range(0,perp_df.shape[0],steps),perp_df['open_time'][:perp_df.shape[0]].loc[::steps],rotation=30)

ax.set_xlabel("Time")
ax.set_ylabel("Price (USDT)")

plt.show()

# %% [markdown]
# ## Spot data

# %%
API_KEY = "Z0GPxBlUJVbpllNE7F5ywtt7LAFOO7ATNYijsDgNUQezWWYvDliiUOjMeMEYRBI8"
SECRET_KEY = "QHOlbP5fpwWO8DxyWT5LH7OkJ5fED7GSgqZxs91LSqKreUXs1KESBN1SkvFzvLdM"
BASE_URL = 'https://api.binance.com'

headers = {
    'X-MBX-APIKEY': API_KEY
}

PATH = '/api/v3/klines'

spot_data = []

for endTime in range(last_time, start_time, -500*3600000):
    startTime = endTime - 499*3600000
        
    params = {
        'symbol': spot_token_pair,
        'interval': '1h',
        'startTime': startTime,
        'endTime': endTime
    }        
    
    temp = []
    
    url = urljoin(BASE_URL, PATH)
    r = requests.get(url, headers=headers, params=params)
    
    if r.status_code == 200:
        temp = list(r.json())
        spot_data = temp + spot_data

# %%
spot_data
# Out:
# [[1568887200000,
#   '9881.43000000',
#   '9881.43000000',
#   '9828.59000000',
#   '9849.75000000',
#   '0.05688900',
#   1568890799999,
#   '560.65782142',
#   10,
#   '0.01979900',
#   '195.33354240',
#   '0'],
#  [1568890800000,
#   '9849.75000000',
#   '9849.75000000',
#   '9849.75000000',
#   '9849.75000000',
#   '0.00000000',
#   1568894399999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568894400000,
#   '9848.41000000',
#   '9858.85000000',
#   '9848.41000000',
#   '9858.85000000',
#   '0.02113800',
#   1568897999999,
#   '208.33128420',
#   4,
#   '0.01983800',
#   '195.52835120',
#   '0'],
#  [1568898000000,
#   '9870.06000000',
#   '9887.21000000',
#   '9866.53000000',
#   '9866.53000000',
#   '0.01252500',
#   1568901599999,
#   '123.60879550',
#   3,
#   '0.00129000',
#   '12.75450090',
#   '0'],
#  [1568901600000,
#   '9866.53000000',
#   '9866.53000000',
#   '9866.53000000',
#   '9866.53000000',
#   '0.00000000',
#   1568905199999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568905200000,
#   '9866.53000000',
#   '9866.53000000',
#   '9866.53000000',
#   '9866.53000000',
#   '0.00000000',
#   1568908799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568908800000,
#   '9875.25000000',
#   '10036.19000000',
#   '9875.25000000',
#   '10036.19000000',
#   '0.14156100',
#   1568912399999,
#   '1417.83941073',
#   18,
#   '0.13605000',
#   '1363.16577171',
#   '0'],
#  [1568912400000,
#   '10036.19000000',
#   '10055.61000000',
#   '10036.19000000',
#   '10053.83000000',
#   '0.01815300',
#   1568915999999,
#   '182.45514001',
#   4,
#   '0.00534800',
#   '53.69305396',
#   '0'],
#  [1568916000000,
#   '10028.02000000',
#   '10034.74000000',
#   '9975.00000000',
#   '9975.00000000',
#   '0.30646400',
#   1568919599999,
#   '3067.53000540',
#   19,
#   '0.04894700',
#   '489.44335754',
#   '0'],
#  [1568919600000,
#   '10038.58000000',
#   '10082.81000000',
#   '10038.58000000',
#   '10082.81000000',
#   '0.02309600',
#   1568923199999,
#   '232.30950141',
#   6,
#   '0.01371200',
#   '138.06949369',
#   '0'],
#  [1568923200000,
#   '10082.81000000',
#   '10276.39000000',
#   '10082.81000000',
#   '10255.46000000',
#   '0.39339900',
#   1568926799999,
#   '4015.38242945',
#   36,
#   '0.29029700',
#   '2957.10868317',
#   '0'],
#  [1568926800000,
#   '10285.69000000',
#   '10305.58000000',
#   '10285.69000000',
#   '10285.91000000',
#   '0.02237100',
#   1568930399999,
#   '230.45809827',
#   4,
#   '0.02094700',
#   '215.81127571',
#   '0'],
#  [1568930400000,
#   '10255.46000000',
#   '10255.46000000',
#   '10249.99000000',
#   '10249.99000000',
#   '0.00559400',
#   1568933999999,
#   '57.35810324',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568934000000,
#   '10250.00000000',
#   '10254.92000000',
#   '10250.00000000',
#   '10254.92000000',
#   '0.04985800',
#   1568937599999,
#   '511.06148384',
#   6,
#   '0.04640600',
#   '475.66150000',
#   '0'],
#  [1568937600000,
#   '10254.92000000',
#   '10254.92000000',
#   '10254.92000000',
#   '10254.92000000',
#   '0.00000000',
#   1568941199999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568941200000,
#   '10254.92000000',
#   '10254.92000000',
#   '10254.92000000',
#   '10254.92000000',
#   '0.00000000',
#   1568944799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568944800000,
#   '10254.92000000',
#   '10254.92000000',
#   '10254.92000000',
#   '10254.92000000',
#   '0.00000000',
#   1568948399999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568948400000,
#   '10214.31000000',
#   '10214.52000000',
#   '10214.31000000',
#   '10214.52000000',
#   '0.00504600',
#   1568951999999,
#   '51.54225288',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568952000000,
#   '10215.02000000',
#   '10230.17000000',
#   '10215.02000000',
#   '10230.17000000',
#   '0.05899900',
#   1568955599999,
#   '602.73654983',
#   11,
#   '0.05331000',
#   '544.62330105',
#   '0'],
#  [1568955600000,
#   '10233.53000000',
#   '10233.53000000',
#   '10185.44000000',
#   '10188.64000000',
#   '0.02261000',
#   1568959199999,
#   '230.43383754',
#   4,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568959200000,
#   '10178.63000000',
#   '10182.77000000',
#   '10178.63000000',
#   '10182.77000000',
#   '0.04174800',
#   1568962799999,
#   '425.03838802',
#   5,
#   '0.03070000',
#   '312.56212490',
#   '0'],
#  [1568962800000,
#   '10168.33000000',
#   '10180.00000000',
#   '10122.86000000',
#   '10164.31000000',
#   '1.22906900',
#   1568966399999,
#   '12467.43909517',
#   29,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568966400000,
#   '10157.84000000',
#   '10175.87000000',
#   '10118.00000000',
#   '10146.91000000',
#   '1.68250400',
#   1568969999999,
#   '17090.76635482',
#   54,
#   '0.05329200',
#   '542.16181643',
#   '0'],
#  [1568970000000,
#   '10148.33000000',
#   '10148.33000000',
#   '10134.17000000',
#   '10137.67000000',
#   '0.06734400',
#   1568973599999,
#   '682.70523072',
#   4,
#   '0.00108600',
#   '11.00570862',
#   '0'],
#  [1568973600000,
#   '10175.03000000',
#   '10181.82000000',
#   '10169.55000000',
#   '10170.60000000',
#   '0.03690000',
#   1568977199999,
#   '375.43394846',
#   6,
#   '0.00139300',
#   '14.16764580',
#   '0'],
#  [1568977200000,
#   '10170.60000000',
#   '10207.48000000',
#   '10118.00000000',
#   '10153.47000000',
#   '1.76556300',
#   1568980799999,
#   '17928.47076038',
#   42,
#   '0.65349000',
#   '6657.87989171',
#   '0'],
#  [1568980800000,
#   '10184.95000000',
#   '10184.95000000',
#   '10161.72000000',
#   '10161.72000000',
#   '0.17334800',
#   1568984399999,
#   '1763.31316446',
#   5,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568984400000,
#   '10207.96000000',
#   '10207.96000000',
#   '10155.34000000',
#   '10155.34000000',
#   '0.23387500',
#   1568987999999,
#   '2378.15816501',
#   5,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568988000000,
#   '10174.19000000',
#   '10176.18000000',
#   '10155.34000000',
#   '10176.18000000',
#   '0.17685900',
#   1568991599999,
#   '1796.74102213',
#   7,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568991600000,
#   '10155.34000000',
#   '10155.34000000',
#   '10155.34000000',
#   '10155.34000000',
#   '0.09267500',
#   1568995199999,
#   '941.14613450',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568995200000,
#   '10155.34000000',
#   '10155.34000000',
#   '10155.34000000',
#   '10155.34000000',
#   '0.00210200',
#   1568998799999,
#   '21.34652468',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1568998800000,
#   '10102.20000000',
#   '10145.26000000',
#   '10078.91000000',
#   '10145.26000000',
#   '0.12344200',
#   1569002399999,
#   '1246.46655962',
#   4,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569002400000,
#   '10148.58000000',
#   '10148.58000000',
#   '10141.99000000',
#   '10141.99000000',
#   '0.00493100',
#   1569005999999,
#   '50.01729625',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569006000000,
#   '10148.89000000',
#   '10148.89000000',
#   '10141.99000000',
#   '10141.99000000',
#   '0.04955800',
#   1569009599999,
#   '502.69433914',
#   4,
#   '0.02050500',
#   '207.96150495',
#   '0'],
#  [1569009600000,
#   '10141.99000000',
#   '10141.99000000',
#   '10141.99000000',
#   '10141.99000000',
#   '0.00000000',
#   1569013199999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569013200000,
#   '10139.67000000',
#   '10141.99000000',
#   '10117.24000000',
#   '10118.02000000',
#   '1.07352400',
#   1569016799999,
#   '10887.27933438',
#   4,
#   '0.02634200',
#   '266.88652831',
#   '0'],
#  [1569016800000,
#   '10145.23000000',
#   '10151.53000000',
#   '10142.37000000',
#   '10142.37000000',
#   '0.07469600',
#   1569020399999,
#   '757.84598208',
#   3,
#   '0.07469600',
#   '757.84598208',
#   '0'],
#  [1569020400000,
#   '10171.06000000',
#   '10171.06000000',
#   '10171.06000000',
#   '10171.06000000',
#   '0.00139100',
#   1569023999999,
#   '14.14794446',
#   1,
#   '0.00139100',
#   '14.14794446',
#   '0'],
#  [1569024000000,
#   '10171.06000000',
#   '10171.06000000',
#   '10171.06000000',
#   '10171.06000000',
#   '0.00000000',
#   1569027599999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569027600000,
#   '10169.44000000',
#   '10169.44000000',
#   '10169.44000000',
#   '10169.44000000',
#   '0.00133400',
#   1569031199999,
#   '13.56603296',
#   1,
#   '0.00133400',
#   '13.56603296',
#   '0'],
#  [1569031200000,
#   '10169.44000000',
#   '10169.44000000',
#   '10169.44000000',
#   '10169.44000000',
#   '0.00000000',
#   1569034799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569034800000,
#   '10169.44000000',
#   '10169.44000000',
#   '10169.44000000',
#   '10169.44000000',
#   '0.00000000',
#   1569038399999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569038400000,
#   '10111.87000000',
#   '10111.87000000',
#   '10111.87000000',
#   '10111.87000000',
#   '0.00947600',
#   1569041999999,
#   '95.82008012',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569042000000,
#   '10111.87000000',
#   '10111.87000000',
#   '10111.87000000',
#   '10111.87000000',
#   '0.00000000',
#   1569045599999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569045600000,
#   '10100.45000000',
#   '10112.81000000',
#   '9957.16000000',
#   '10038.39000000',
#   '0.74188500',
#   1569049199999,
#   '7407.90817196',
#   12,
#   '0.00366700',
#   '36.87523531',
#   '0'],
#  [1569049200000,
#   '10086.94000000',
#   '10086.94000000',
#   '10081.35000000',
#   '10081.35000000',
#   '0.02272900',
#   1569052799999,
#   '229.25290599',
#   2,
#   '0.02272900',
#   '229.25290599',
#   '0'],
#  [1569052800000,
#   '10000.00000000',
#   '10000.00000000',
#   '9986.27000000',
#   '9986.27000000',
#   '0.08253400',
#   1569056399999,
#   '824.22465718',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569056400000,
#   '10012.25000000',
#   '10020.30000000',
#   '9999.28000000',
#   '9999.28000000',
#   '0.11655100',
#   1569059999999,
#   '1166.90126218',
#   6,
#   '0.06382600',
#   '638.86040768',
#   '0'],
#  [1569060000000,
#   '9999.27000000',
#   '9999.27000000',
#   '9998.37000000',
#   '9998.37000000',
#   '0.48130500',
#   1569063599999,
#   '4812.57691245',
#   7,
#   '0.46064700',
#   '4606.02086049',
#   '0'],
#  [1569063600000,
#   '10045.77000000',
#   '10045.77000000',
#   '10045.77000000',
#   '10045.77000000',
#   '0.02212900',
#   1569067199999,
#   '222.30284433',
#   1,
#   '0.02212900',
#   '222.30284433',
#   '0'],
#  [1569067200000,
#   '10039.63000000',
#   '10039.63000000',
#   '9940.27000000',
#   '9950.00000000',
#   '1.34978000',
#   1569070799999,
#   '13460.55282238',
#   15,
#   '1.24158400',
#   '12383.53116337',
#   '0'],
#  [1569070800000,
#   '9952.76000000',
#   '9981.07000000',
#   '9952.76000000',
#   '9981.07000000',
#   '0.01463600',
#   1569074399999,
#   '145.73727542',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569074400000,
#   '9981.07000000',
#   '9981.07000000',
#   '9981.07000000',
#   '9981.07000000',
#   '0.00000000',
#   1569077999999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569078000000,
#   '10028.02000000',
#   '10028.02000000',
#   '9974.50000000',
#   '9974.50000000',
#   '0.13549500',
#   1569081599999,
#   '1354.64590744',
#   10,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569081600000,
#   '10049.95000000',
#   '10049.95000000',
#   '10049.95000000',
#   '10049.95000000',
#   '0.02704700',
#   1569085199999,
#   '271.82099765',
#   1,
#   '0.02704700',
#   '271.82099765',
#   '0'],
#  [1569085200000,
#   '9978.03000000',
#   '9978.03000000',
#   '9978.03000000',
#   '9978.03000000',
#   '0.00100100',
#   1569088799999,
#   '9.98800803',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569088800000,
#   '9985.14000000',
#   '9998.32000000',
#   '9985.14000000',
#   '9985.14000000',
#   '0.02257000',
#   1569092399999,
#   '225.51297706',
#   4,
#   '0.01125700',
#   '112.55108824',
#   '0'],
#  [1569092400000,
#   '9998.87000000',
#   '10005.72000000',
#   '9998.87000000',
#   '10005.72000000',
#   '0.00398100',
#   1569095999999,
#   '39.82590077',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569096000000,
#   '9998.87000000',
#   '9998.87000000',
#   '9998.87000000',
#   '9998.87000000',
#   '0.00389600',
#   1569099599999,
#   '38.95559752',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569099600000,
#   '9978.63000000',
#   '9978.63000000',
#   '9978.63000000',
#   '9978.63000000',
#   '0.00106100',
#   1569103199999,
#   '10.58732643',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569103200000,
#   '9958.52000000',
#   '9978.70000000',
#   '9958.52000000',
#   '9978.70000000',
#   '0.01304700',
#   1569106799999,
#   '130.13061044',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569106800000,
#   '9998.87000000',
#   '9998.87000000',
#   '9998.87000000',
#   '9998.87000000',
#   '0.00257400',
#   1569110399999,
#   '25.73709138',
#   1,
#   '0.00257400',
#   '25.73709138',
#   '0'],
#  [1569110400000,
#   '9998.87000000',
#   '9998.87000000',
#   '9998.87000000',
#   '9998.87000000',
#   '0.00000000',
#   1569113999999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569114000000,
#   '9928.07000000',
#   '9928.07000000',
#   '9874.30000000',
#   '9901.14000000',
#   '1.19812300',
#   1569117599999,
#   '11862.70826129',
#   12,
#   '1.19702600',
#   '11851.81716850',
#   '0'],
#  [1569117600000,
#   '9901.14000000',
#   '9901.14000000',
#   '9901.14000000',
#   '9901.14000000',
#   '0.00000000',
#   1569121199999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569121200000,
#   '9901.14000000',
#   '9901.14000000',
#   '9901.14000000',
#   '9901.14000000',
#   '0.00000000',
#   1569124799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569124800000,
#   '9880.97000000',
#   '9880.97000000',
#   '9880.97000000',
#   '9880.97000000',
#   '0.00997200',
#   1569128399999,
#   '98.53303284',
#   1,
#   '0.00997200',
#   '98.53303284',
#   '0'],
#  [1569128400000,
#   '9911.25000000',
#   '9948.61000000',
#   '9906.57000000',
#   '9948.61000000',
#   '0.05814100',
#   1569131999999,
#   '576.87820983',
#   4,
#   '0.05814100',
#   '576.87820983',
#   '0'],
#  [1569132000000,
#   '9948.61000000',
#   '9948.61000000',
#   '9948.61000000',
#   '9948.61000000',
#   '0.00000000',
#   1569135599999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569135600000,
#   '9965.21000000',
#   '10018.88000000',
#   '9965.21000000',
#   '10012.56000000',
#   '0.11600300',
#   1569139199999,
#   '1160.01279286',
#   5,
#   '0.11600300',
#   '1160.01279286',
#   '0'],
#  [1569139200000,
#   '10012.56000000',
#   '10012.56000000',
#   '10012.56000000',
#   '10012.56000000',
#   '0.00000000',
#   1569142799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569142800000,
#   '9986.14000000',
#   '9986.14000000',
#   '9986.14000000',
#   '9986.14000000',
#   '0.01284800',
#   1569146399999,
#   '128.30192672',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569146400000,
#   '10024.50000000',
#   '10024.50000000',
#   '10024.50000000',
#   '10024.50000000',
#   '0.00302300',
#   1569149999999,
#   '30.30406350',
#   1,
#   '0.00302300',
#   '30.30406350',
#   '0'],
#  [1569150000000,
#   '10005.94000000',
#   '10005.94000000',
#   '10005.94000000',
#   '10005.94000000',
#   '0.00499200',
#   1569153599999,
#   '49.94965248',
#   1,
#   '0.00499200',
#   '49.94965248',
#   '0'],
#  [1569153600000,
#   '10007.49000000',
#   '10037.95000000',
#   '10005.95000000',
#   '10023.91000000',
#   '0.12125600',
#   1569157199999,
#   '1215.00830498',
#   6,
#   '0.03866600',
#   '386.89006270',
#   '0'],
#  [1569157200000,
#   '10030.46000000',
#   '10030.46000000',
#   '10023.91000000',
#   '10023.91000000',
#   '0.01403600',
#   1569160799999,
#   '140.77428591',
#   2,
#   '0.00202300',
#   '20.27836993',
#   '0'],
#  [1569160800000,
#   '9964.72000000',
#   '9964.72000000',
#   '9950.50000000',
#   '9952.61000000',
#   '0.04298400',
#   1569164399999,
#   '427.78269667',
#   7,
#   '0.04183000',
#   '416.29643845',
#   '0'],
#  [1569164400000,
#   '9952.61000000',
#   '9952.61000000',
#   '9952.61000000',
#   '9952.61000000',
#   '0.00000000',
#   1569167999999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569168000000,
#   '9952.61000000',
#   '9952.61000000',
#   '9952.61000000',
#   '9952.61000000',
#   '0.00000000',
#   1569171599999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569171600000,
#   '9952.61000000',
#   '9952.61000000',
#   '9952.61000000',
#   '9952.61000000',
#   '0.00000000',
#   1569175199999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569175200000,
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '0.00220000',
#   1569178799999,
#   '21.97217000',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569178800000,
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '0.05718000',
#   1569182399999,
#   '571.07667300',
#   2,
#   '0.05718000',
#   '571.07667300',
#   '0'],
#  [1569182400000,
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '0.00000000',
#   1569185999999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569186000000,
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '9987.35000000',
#   '0.00000000',
#   1569189599999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569189600000,
#   '10050.12000000',
#   '10050.12000000',
#   '10038.00000000',
#   '10038.00000000',
#   '0.01694700',
#   1569193199999,
#   '170.13627468',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569193200000,
#   '10021.29000000',
#   '10021.29000000',
#   '10000.79000000',
#   '10010.53000000',
#   '0.13994800',
#   1569196799999,
#   '1401.37478458',
#   12,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569196800000,
#   '10037.70000000',
#   '10037.70000000',
#   '9981.51000000',
#   '9981.51000000',
#   '0.13015000',
#   1569200399999,
#   '1300.78765500',
#   3,
#   '0.10000000',
#   '998.15100000',
#   '0'],
#  [1569200400000,
#   '9980.37000000',
#   '9981.28000000',
#   '9980.37000000',
#   '9981.28000000',
#   '0.11396800',
#   1569203999999,
#   '1137.53380816',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569204000000,
#   '9988.48000000',
#   '9988.48000000',
#   '9979.05000000',
#   '9979.05000000',
#   '0.08981000',
#   1569207599999,
#   '897.05533642',
#   2,
#   '0.08981000',
#   '897.05533642',
#   '0'],
#  [1569207600000,
#   '9953.44000000',
#   '9967.02000000',
#   '9948.18000000',
#   '9967.02000000',
#   '0.25153400',
#   1569211199999,
#   '2503.33449133',
#   11,
#   '0.25153400',
#   '2503.33449133',
#   '0'],
#  [1569211200000,
#   '9970.20000000',
#   '9977.89000000',
#   '9957.58000000',
#   '9957.58000000',
#   '0.72734400',
#   1569214799999,
#   '7250.52113690',
#   36,
#   '0.72734400',
#   '7250.52113690',
#   '0'],
#  [1569214800000,
#   '9933.01000000',
#   '9933.01000000',
#   '9933.01000000',
#   '9933.01000000',
#   '0.00157300',
#   1569218399999,
#   '15.62462473',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569218400000,
#   '9942.18000000',
#   '9942.18000000',
#   '9864.75000000',
#   '9898.67000000',
#   '1.17371900',
#   1569221999999,
#   '11619.70680049',
#   28,
#   '0.53996700',
#   '5351.33471735',
#   '0'],
#  [1569222000000,
#   '9914.84000000',
#   '9914.84000000',
#   '9888.98000000',
#   '9901.79000000',
#   '1.44378000',
#   1569225599999,
#   '14289.24619092',
#   15,
#   '0.02019500',
#   '199.96664905',
#   '0'],
#  [1569225600000,
#   '9912.52000000',
#   '9938.19000000',
#   '9912.52000000',
#   '9926.43000000',
#   '0.28661900',
#   1569229199999,
#   '2845.56334955',
#   10,
#   '0.06540200',
#   '648.96098840',
#   '0'],
#  [1569229200000,
#   '9953.32000000',
#   '9953.32000000',
#   '9946.73000000',
#   '9946.73000000',
#   '0.00375600',
#   1569232799999,
#   '37.36657378',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569232800000,
#   '9926.01000000',
#   '9936.07000000',
#   '9926.01000000',
#   '9932.87000000',
#   '0.41135200',
#   1569236399999,
#   '4085.09922889',
#   7,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569236400000,
#   '9932.87000000',
#   '9932.87000000',
#   '9927.74000000',
#   '9927.74000000',
#   '0.02629200',
#   1569239999999,
#   '261.04572339',
#   2,
#   '0.00498700',
#   '49.53522269',
#   '0'],
#  [1569240000000,
#   '9900.63000000',
#   '9910.14000000',
#   '9876.85000000',
#   '9910.14000000',
#   '0.61837800',
#   1569243599999,
#   '6114.76574628',
#   12,
#   '0.02024100',
#   '199.93290642',
#   '0'],
#  [1569243600000,
#   '9895.86000000',
#   '9899.01000000',
#   '9895.86000000',
#   '9899.01000000',
#   '0.03102200',
#   1569247199999,
#   '307.05874452',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569247200000,
#   '9880.59000000',
#   '9922.29000000',
#   '9684.11000000',
#   '9922.29000000',
#   '4.75731900',
#   1569250799999,
#   '46643.89980126',
#   104,
#   '0.40134900',
#   '3936.33335918',
#   '0'],
#  [1569250800000,
#   '9879.44000000',
#   '9879.44000000',
#   '9854.25000000',
#   '9854.25000000',
#   '1.10240000',
#   1569254399999,
#   '10867.84575412',
#   7,
#   '0.10000000',
#   '987.70800000',
#   '0'],
#  [1569254400000,
#   '9864.03000000',
#   '9873.96000000',
#   '9791.17000000',
#   '9791.17000000',
#   '0.46137000',
#   1569257999999,
#   '4539.41654927',
#   14,
#   '0.25871500',
#   '2544.60092343',
#   '0'],
#  [1569258000000,
#   '9806.51000000',
#   '9806.51000000',
#   '9800.60000000',
#   '9802.68000000',
#   '0.12056900',
#   1569261599999,
#   '1181.99120854',
#   5,
#   '0.00341800',
#   '33.50665400',
#   '0'],
#  [1569261600000,
#   '9817.03000000',
#   '9817.03000000',
#   '9817.03000000',
#   '9817.03000000',
#   '0.00563100',
#   1569265199999,
#   '55.27969593',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569265200000,
#   '9810.20000000',
#   '9810.20000000',
#   '9810.19000000',
#   '9810.19000000',
#   '0.03675500',
#   1569268799999,
#   '360.57381125',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569268800000,
#   '9802.22000000',
#   '9802.22000000',
#   '9748.43000000',
#   '9768.22000000',
#   '1.59057000',
#   1569272399999,
#   '15516.77852035',
#   28,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569272400000,
#   '9772.00000000',
#   '9776.01000000',
#   '9659.96000000',
#   '9759.79000000',
#   '11.45572400',
#   1569275999999,
#   '111174.98707517',
#   315,
#   '1.19931200',
#   '11656.92749392',
#   '0'],
#  [1569276000000,
#   '9739.48000000',
#   '9739.48000000',
#   '9612.75000000',
#   '9721.63000000',
#   '2.67566100',
#   1569279599999,
#   '25795.30480362',
#   50,
#   '0.73799900',
#   '7138.27880487',
#   '0'],
#  [1569279600000,
#   '9727.28000000',
#   '9727.28000000',
#   '9706.93000000',
#   '9706.93000000',
#   '0.63048200',
#   1569283199999,
#   '6125.03960265',
#   10,
#   '0.05043500',
#   '489.56901455',
#   '0'],
#  [1569283200000,
#   '9675.42000000',
#   '9686.25000000',
#   '9597.00000000',
#   '9686.25000000',
#   '5.22996300',
#   1569286799999,
#   '50404.87847008',
#   72,
#   '0.84637500',
#   '8174.41054823',
#   '0'],
#  [1569286800000,
#   '9753.66000000',
#   '9780.75000000',
#   '9738.75000000',
#   '9739.18000000',
#   '1.01798800',
#   1569290399999,
#   '9923.86920046',
#   14,
#   '0.10829200',
#   '1058.24989183',
#   '0'],
#  [1569290400000,
#   '9700.24000000',
#   '9700.24000000',
#   '9692.73000000',
#   '9692.73000000',
#   '0.23329700',
#   1569293999999,
#   '2262.28389099',
#   6,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569294000000,
#   '9708.14000000',
#   '9727.17000000',
#   '9677.98000000',
#   '9727.17000000',
#   '1.55936400',
#   1569297599999,
#   '15112.31044565',
#   45,
#   '0.08550200',
#   '828.34094293',
#   '0'],
#  [1569297600000,
#   '9699.44000000',
#   '9728.25000000',
#   '9694.16000000',
#   '9717.81000000',
#   '1.36155700',
#   1569301199999,
#   '13235.19298846',
#   17,
#   '0.93775400',
#   '9121.08953427',
#   '0'],
#  [1569301200000,
#   '9717.81000000',
#   '9717.81000000',
#   '9717.81000000',
#   '9717.81000000',
#   '0.00000000',
#   1569304799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569304800000,
#   '9783.10000000',
#   '9783.10000000',
#   '9783.10000000',
#   '9783.10000000',
#   '0.07186200',
#   1569308399999,
#   '703.03313220',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569308400000,
#   '9763.86000000',
#   '9763.86000000',
#   '9731.36000000',
#   '9731.36000000',
#   '0.34299300',
#   1569311999999,
#   '3340.45501900',
#   7,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569312000000,
#   '9752.37000000',
#   '9752.37000000',
#   '9692.88000000',
#   '9718.54000000',
#   '2.31060900',
#   1569315599999,
#   '22439.35035312',
#   31,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569315600000,
#   '9694.54000000',
#   '9739.84000000',
#   '9694.54000000',
#   '9733.50000000',
#   '0.21806800',
#   1569319199999,
#   '2118.64718086',
#   5,
#   '0.13807300',
#   '1339.86926284',
#   '0'],
#  [1569319200000,
#   '9717.02000000',
#   '9733.50000000',
#   '9711.40000000',
#   '9733.50000000',
#   '0.85225800',
#   1569322799999,
#   '8279.78684197',
#   9,
#   '0.10105000',
#   '983.45561583',
#   '0'],
#  [1569322800000,
#   '9726.65000000',
#   '9727.35000000',
#   '9695.06000000',
#   '9695.06000000',
#   '0.67852600',
#   1569326399999,
#   '6593.79539046',
#   17,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569326400000,
#   '9719.61000000',
#   '9719.61000000',
#   '9660.98000000',
#   '9689.24000000',
#   '1.01500900',
#   1569329999999,
#   '9818.36441896',
#   20,
#   '0.05512500',
#   '533.92551671',
#   '0'],
#  [1569330000000,
#   '9670.52000000',
#   '9670.52000000',
#   '9595.00000000',
#   '9611.00000000',
#   '0.60016700',
#   1569333599999,
#   '5785.87547044',
#   15,
#   '0.10520000',
#   '1016.52178250',
#   '0'],
#  [1569333600000,
#   '9622.23000000',
#   '9622.23000000',
#   '9522.72000000',
#   '9528.35000000',
#   '2.22838100',
#   1569337199999,
#   '21283.97494175',
#   50,
#   '0.45219600',
#   '4326.72070076',
#   '0'],
#  [1569337200000,
#   '9510.36000000',
#   '9549.10000000',
#   '9427.43000000',
#   '9517.05000000',
#   '9.33014500',
#   1569340799999,
#   '88472.36879740',
#   221,
#   '0.35725700',
#   '3385.39333521',
#   '0'],
#  [1569340800000,
#   '9515.49000000',
#   '9591.75000000',
#   '9474.79000000',
#   '9494.00000000',
#   '6.50330300',
#   1569344399999,
#   '62189.07534300',
#   181,
#   '0.34441200',
#   '3291.48983542',
#   '0'],
#  [1569344400000,
#   '9471.87000000',
#   '9514.31000000',
#   '9451.11000000',
#   '9482.58000000',
#   '1.91617500',
#   1569347999999,
#   '18164.63098422',
#   30,
#   '0.42182100',
#   '4002.19475879',
#   '0'],
#  [1569348000000,
#   '9478.10000000',
#   '9478.10000000',
#   '8441.27000000',
#   '8636.55000000',
#   '11.38987300',
#   1569351599999,
#   '104729.99075185',
#   384,
#   '0.46503300',
#   '4165.89353816',
#   '0'],
#  [1569351600000,
#   '8558.43000000',
#   '8735.81000000',
#   '1800.00000000',
#   '8371.86000000',
#   '9.54051900',
#   1569355199999,
#   '78489.07386416',
#   302,
#   '3.67470800',
#   '30695.65788562',
#   '0'],
#  [1569355200000,
#   '8431.50000000',
#   '8650.00000000',
#   '8090.25000000',
#   '8586.43000000',
#   '3.38277900',
#   1569358799999,
#   '28208.36848764',
#   58,
#   '1.04358800',
#   '8866.76117969',
#   '0'],
#  [1569358800000,
#   '8580.46000000',
#   '8769.57000000',
#   '8508.19000000',
#   '8710.81000000',
#   '1.29295300',
#   1569362399999,
#   '11092.15802388',
#   36,
#   '0.62832700',
#   '5397.68234395',
#   '0'],
#  [1569362400000,
#   '8679.00000000',
#   '8762.50000000',
#   '8631.61000000',
#   '8675.53000000',
#   '1.32906400',
#   1569365999999,
#   '11541.09200115',
#   17,
#   '0.85325800',
#   '7411.13556044',
#   '0'],
#  [1569366000000,
#   '8694.76000000',
#   '8791.24000000',
#   '8499.75000000',
#   '8499.75000000',
#   '2.61567200',
#   1569369599999,
#   '22426.32950885',
#   37,
#   '0.36485000',
#   '3144.22719061',
#   '0'],
#  [1569369600000,
#   '8558.92000000',
#   '8728.04000000',
#   '8558.92000000',
#   '8728.04000000',
#   '0.53530500',
#   1569373199999,
#   '4613.25691097',
#   16,
#   '0.33148100',
#   '2853.47449961',
#   '0'],
#  [1569373200000,
#   '8662.39000000',
#   '8699.53000000',
#   '8662.39000000',
#   '8699.53000000',
#   '0.15358300',
#   1569376799999,
#   '1334.37107853',
#   6,
#   '0.13602800',
#   '1182.30282208',
#   '0'],
#  [1569376800000,
#   '8700.91000000',
#   '8700.91000000',
#   '8653.01000000',
#   '8653.01000000',
#   '0.13373400',
#   1569380399999,
#   '1158.58205434',
#   3,
#   '0.02988400',
#   '258.58655084',
#   '0'],
#  [1569380400000,
#   '8614.86000000',
#   '8614.86000000',
#   '8571.53000000',
#   '8571.53000000',
#   '0.05049000',
#   1569383999999,
#   '433.87041555',
#   2,
#   '0.02524500',
#   '217.48214070',
#   '0'],
#  [1569384000000,
#   '8529.53000000',
#   '8547.00000000',
#   '8450.00000000',
#   '8489.25000000',
#   '0.99942300',
#   1569387599999,
#   '8506.88445861',
#   10,
#   '0.32214600',
#   '2752.26325724',
#   '0'],
#  [1569387600000,
#   '8516.00000000',
#   '8516.00000000',
#   '8471.90000000',
#   '8511.74000000',
#   '0.37769400',
#   1569391199999,
#   '3204.99962642',
#   11,
#   '0.36148500',
#   '3067.35133961',
#   '0'],
#  [1569391200000,
#   '8516.40000000',
#   '8527.30000000',
#   '8467.46000000',
#   '8467.46000000',
#   '0.56628100',
#   1569394799999,
#   '4817.23570166',
#   12,
#   '0.21453800',
#   '1828.48834464',
#   '0'],
#  [1569394800000,
#   '8465.92000000',
#   '8467.21000000',
#   '8351.67000000',
#   '8351.67000000',
#   '0.81440900',
#   1569398399999,
#   '6878.74092276',
#   27,
#   '0.27948700',
#   '2358.40797703',
#   '0'],
#  [1569398400000,
#   '8330.95000000',
#   '8330.95000000',
#   '8238.19000000',
#   '8238.19000000',
#   '3.35347400',
#   1569401999999,
#   '27739.90704111',
#   42,
#   '3.08418400',
#   '25503.22701381',
#   '0'],
#  [1569402000000,
#   '8255.45000000',
#   '8397.00000000',
#   '8255.45000000',
#   '8389.01000000',
#   '1.17615600',
#   1569405599999,
#   '9788.64201971',
#   32,
#   '1.00473300',
#   '8354.53667075',
#   '0'],
#  [1569405600000,
#   '8418.85000000',
#   '8430.60000000',
#   '8400.55000000',
#   '8409.97000000',
#   '0.44838600',
#   1569409199999,
#   '3777.18633347',
#   13,
#   '0.31675400',
#   '2668.21025731',
#   '0'],
#  [1569409200000,
#   '8425.08000000',
#   '8425.08000000',
#   '8310.99000000',
#   '8345.43000000',
#   '2.08487000',
#   1569412799999,
#   '17479.09719049',
#   23,
#   '1.14804400',
#   '9623.18662981',
#   '0'],
#  [1569412800000,
#   '8252.10000000',
#   '8305.28000000',
#   '8247.75000000',
#   '8305.28000000',
#   '0.50866400',
#   1569416399999,
#   '4199.09379236',
#   8,
#   '0.14728800',
#   '1218.22990385',
#   '0'],
#  [1569416400000,
#   '8309.00000000',
#   '8415.15000000',
#   '8309.00000000',
#   '8385.80000000',
#   '1.59457300',
#   1569419999999,
#   '13373.05214548',
#   27,
#   '0.81333000',
#   '6829.35479268',
#   '0'],
#  [1569420000000,
#   '8420.11000000',
#   '8420.11000000',
#   '8388.53000000',
#   '8399.00000000',
#   '1.77360700',
#   1569423599999,
#   '14906.96261143',
#   17,
#   '0.23967300',
#   '2016.94017758',
#   '0'],
#  [1569423600000,
#   '8399.00000000',
#   '8413.09000000',
#   '8300.00000000',
#   '8300.00000000',
#   '1.16916400',
#   1569427199999,
#   '9821.21491666',
#   19,
#   '1.16267200',
#   '9767.06334214',
#   '0'],
#  [1569427200000,
#   '8300.00000000',
#   '8343.87000000',
#   '8225.58000000',
#   '8337.59000000',
#   '2.27471000',
#   1569430799999,
#   '18845.55017758',
#   38,
#   '1.37298400',
#   '11402.85261783',
#   '0'],
#  [1569430800000,
#   '8355.50000000',
#   '8413.44000000',
#   '8339.57000000',
#   '8377.11000000',
#   '1.71671100',
#   1569434399999,
#   '14374.59068735',
#   30,
#   '1.67612500',
#   '14034.92633645',
#   '0'],
#  [1569434400000,
#   '8377.11000000',
#   '8377.11000000',
#   '8377.11000000',
#   '8377.11000000',
#   '0.00000000',
#   1569437999999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569438000000,
#   '8340.09000000',
#   '8343.38000000',
#   '8319.74000000',
#   '8343.38000000',
#   '0.20095000',
#   1569441599999,
#   '1672.36102291',
#   5,
#   '0.02363500',
#   '196.67775490',
#   '0'],
#  [1569441600000,
#   '8354.28000000',
#   '8507.55000000',
#   '8354.28000000',
#   '8490.86000000',
#   '3.86815300',
#   1569445199999,
#   '32567.80443826',
#   33,
#   '3.80964700',
#   '32072.71380647',
#   '0'],
#  [1569445200000,
#   '8511.00000000',
#   '8581.33000000',
#   '8511.00000000',
#   '8578.78000000',
#   '0.94838100',
#   1569448799999,
#   '8102.57459346',
#   23,
#   '0.63389100',
#   '5417.55848033',
#   '0'],
#  [1569448800000,
#   '8587.00000000',
#   '8623.82000000',
#   '8434.88000000',
#   '8450.23000000',
#   '3.53398800',
#   1569452399999,
#   '30142.87531791',
#   49,
#   '2.30474000',
#   '19711.07933600',
#   '0'],
#  [1569452400000,
#   '8426.00000000',
#   '8436.75000000',
#   '8329.27000000',
#   '8436.75000000',
#   '1.77682000',
#   1569455999999,
#   '14930.78527713',
#   31,
#   '0.34258600',
#   '2877.11555638',
#   '0'],
#  [1569456000000,
#   '8415.14000000',
#   '8415.14000000',
#   '8400.28000000',
#   '8401.51000000',
#   '0.48253700',
#   1569459599999,
#   '4055.89992573',
#   6,
#   '0.00619800',
#   '52.07255898',
#   '0'],
#  [1569459600000,
#   '8383.31000000',
#   '8404.07000000',
#   '8346.19000000',
#   '8346.19000000',
#   '0.34979500',
#   1569463199999,
#   '2924.92854410',
#   18,
#   '0.02555100',
#   '214.16208870',
#   '0'],
#  [1569463200000,
#   '8344.93000000',
#   '8356.28000000',
#   '8344.63000000',
#   '8356.28000000',
#   '0.15966900',
#   1569466799999,
#   '1332.73034637',
#   5,
#   '0.13944500',
#   '1163.96248205',
#   '0'],
#  [1569466800000,
#   '8375.86000000',
#   '8389.89000000',
#   '8375.86000000',
#   '8389.84000000',
#   '0.96156200',
#   1569470399999,
#   '8053.98133733',
#   7,
#   '0.95896700',
#   '8032.20957278',
#   '0'],
#  [1569470400000,
#   '8357.13000000',
#   '8363.25000000',
#   '8341.19000000',
#   '8341.19000000',
#   '0.25083500',
#   1569473999999,
#   '2095.78559371',
#   7,
#   '0.17222200',
#   '1440.02361062',
#   '0'],
#  [1569474000000,
#   '8341.19000000',
#   '8341.19000000',
#   '8341.19000000',
#   '8341.19000000',
#   '0.00000000',
#   1569477599999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569477600000,
#   '8412.58000000',
#   '8412.58000000',
#   '8396.31000000',
#   '8396.31000000',
#   '0.22087400',
#   1569481199999,
#   '1855.42728261',
#   3,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569481200000,
#   '8397.89000000',
#   '8405.79000000',
#   '8369.57000000',
#   '8379.72000000',
#   '1.03448200',
#   1569484799999,
#   '8681.98952916',
#   19,
#   '0.11346300',
#   '953.62431557',
#   '0'],
#  [1569484800000,
#   '8396.54000000',
#   '8413.67000000',
#   '8396.54000000',
#   '8413.67000000',
#   '0.04922900',
#   1569488399999,
#   '413.78800993',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569488400000,
#   '8421.27000000',
#   '8461.31000000',
#   '8408.38000000',
#   '8461.31000000',
#   '0.07535700',
#   1569491999999,
#   '635.28602141',
#   9,
#   '0.04197300',
#   '354.24995682',
#   '0'],
#  [1569492000000,
#   '8422.80000000',
#   '8422.80000000',
#   '8409.88000000',
#   '8410.50000000',
#   '0.75524100',
#   1569495599999,
#   '6352.71120986',
#   9,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569495600000,
#   '8439.33000000',
#   '8439.33000000',
#   '8396.69000000',
#   '8423.92000000',
#   '1.25865600',
#   1569499199999,
#   '10593.92108075',
#   15,
#   '0.95000000',
#   '7999.71356039',
#   '0'],
#  [1569499200000,
#   '8395.56000000',
#   '8426.54000000',
#   '8395.56000000',
#   '8426.54000000',
#   '0.46724700',
#   1569502799999,
#   '3932.15177409',
#   10,
#   '0.19200000',
#   '1615.57632000',
#   '0'],
#  [1569502800000,
#   '8418.82000000',
#   '8424.48000000',
#   '7200.00000000',
#   '8219.48000000',
#   '16.09343800',
#   1569506399999,
#   '131873.92318872',
#   239,
#   '6.45512700',
#   '52530.16415935',
#   '0'],
#  [1569506400000,
#   '8262.34000000',
#   '8409.58000000',
#   '8150.24000000',
#   '8181.07000000',
#   '4.92973200',
#   1569509999999,
#   '40866.68461461',
#   86,
#   '2.75408600',
#   '22874.25345790',
#   '0'],
#  [1569510000000,
#   '8169.95000000',
#   '8206.28000000',
#   '7871.52000000',
#   '7925.49000000',
#   '13.20237500',
#   1569513599999,
#   '105984.47656977',
#   236,
#   '4.67705400',
#   '38156.46761145',
#   '0'],
#  [1569513600000,
#   '7928.09000000',
#   '8011.66000000',
#   '7737.14000000',
#   '7943.84000000',
#   '25.40585300',
#   1569517199999,
#   '200365.32772759',
#   561,
#   '2.72979300',
#   '21597.32157498',
#   '0'],
#  [1569517200000,
#   '7929.38000000',
#   '7956.22000000',
#   '7878.96000000',
#   '7921.87000000',
#   '2.10017000',
#   1569520799999,
#   '16651.41962652',
#   44,
#   '0.38077700',
#   '3015.14174363',
#   '0'],
#  [1569520800000,
#   '7922.49000000',
#   '8166.06000000',
#   '7919.76000000',
#   '8114.14000000',
#   '4.56535700',
#   1569524399999,
#   '36903.23512805',
#   35,
#   '0.70105500',
#   '5676.33683280',
#   '0'],
#  [1569524400000,
#   '8090.00000000',
#   '8121.75000000',
#   '8056.83000000',
#   '8121.75000000',
#   '2.42564500',
#   1569527999999,
#   '19594.72511641',
#   42,
#   '1.63346700',
#   '13192.05781947',
#   '0'],
#  [1569528000000,
#   '8112.36000000',
#   '8147.81000000',
#   '8108.72000000',
#   '8108.72000000',
#   '1.42793700',
#   1569531599999,
#   '11592.80312541',
#   9,
#   '1.00789300',
#   '8180.46165081',
#   '0'],
#  [1569531600000,
#   '8088.81000000',
#   '8088.81000000',
#   '8017.91000000',
#   '8057.27000000',
#   '0.30955900',
#   1569535199999,
#   '2494.10390754',
#   6,
#   '0.11048900',
#   '886.30370503',
#   '0'],
#  [1569535200000,
#   '8073.11000000',
#   '8131.36000000',
#   '8022.76000000',
#   '8131.36000000',
#   '0.44636900',
#   1569538799999,
#   '3610.30749017',
#   11,
#   '0.21480700',
#   '1744.21886583',
#   '0'],
#  [1569538800000,
#   '8100.89000000',
#   '8100.89000000',
#   '8067.78000000',
#   '8067.78000000',
#   '0.16593500',
#   1569542399999,
#   '1342.79351517',
#   4,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569542400000,
#   '8067.78000000',
#   '8067.78000000',
#   '7964.89000000',
#   '7964.89000000',
#   '0.18816300',
#   1569545999999,
#   '1507.58226750',
#   10,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569546000000,
#   '7957.25000000',
#   '8000.00000000',
#   '7940.06000000',
#   '8000.00000000',
#   '0.46318500',
#   1569549599999,
#   '3693.51592013',
#   9,
#   '0.03142000',
#   '251.36000000',
#   '0'],
#  [1569549600000,
#   '7973.58000000',
#   '7979.68000000',
#   '7972.25000000',
#   '7979.68000000',
#   '0.14895500',
#   1569553199999,
#   '1187.67455320',
#   4,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569553200000,
#   '8012.85000000',
#   '8048.35000000',
#   '8008.17000000',
#   '8008.17000000',
#   '0.07608600',
#   1569556799999,
#   '610.15112075',
#   8,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569556800000,
#   '8031.79000000',
#   '8031.79000000',
#   '7981.61000000',
#   '7981.61000000',
#   '1.72115800',
#   1569560399999,
#   '13796.14381807',
#   22,
#   '0.68156000',
#   '5464.27130956',
#   '0'],
#  [1569560400000,
#   '7990.59000000',
#   '7990.59000000',
#   '7960.64000000',
#   '7966.94000000',
#   '0.10842100',
#   1569563999999,
#   '863.94845748',
#   7,
#   '0.03891100',
#   '310.03686767',
#   '0'],
#  [1569564000000,
#   '8016.75000000',
#   '8016.75000000',
#   '8016.75000000',
#   '8016.75000000',
#   '1.88718300',
#   1569567599999,
#   '15129.07431525',
#   5,
#   '1.88718300',
#   '15129.07431525',
#   '0'],
#  [1569567600000,
#   '8041.65000000',
#   '8082.23000000',
#   '8041.65000000',
#   '8058.75000000',
#   '2.27738300',
#   1569571199999,
#   '18359.00779585',
#   83,
#   '0.43638100',
#   '3515.60960808',
#   '0'],
#  [1569571200000,
#   '8057.18000000',
#   '8125.53000000',
#   '8054.69000000',
#   '8068.22000000',
#   '1.45822200',
#   1569574799999,
#   '11799.71500741',
#   57,
#   '0.07206400',
#   '583.63996496',
#   '0'],
#  [1569574800000,
#   '8050.13000000',
#   '8050.13000000',
#   '8022.49000000',
#   '8022.49000000',
#   '0.86498600',
#   1569578399999,
#   '6948.96290252',
#   13,
#   '0.01766500',
#   '141.96141615',
#   '0'],
#  [1569578400000,
#   '8051.85000000',
#   '8058.65000000',
#   '8041.80000000',
#   '8057.50000000',
#   '0.02233900',
#   1569581999999,
#   '179.96975480',
#   5,
#   '0.00136800',
#   '11.00118240',
#   '0'],
#  [1569582000000,
#   '8045.63000000',
#   '8045.63000000',
#   '7949.54000000',
#   '7949.54000000',
#   '1.35432000',
#   1569585599999,
#   '10784.90778233',
#   20,
#   '0.00403900',
#   '32.49629957',
#   '0'],
#  [1569585600000,
#   '7963.79000000',
#   '8002.40000000',
#   '7951.05000000',
#   '7986.67000000',
#   '0.69151900',
#   1569589199999,
#   '5507.28752021',
#   17,
#   '0.04671700',
#   '373.07578183',
#   '0'],
#  [1569589200000,
#   '7997.52000000',
#   '8005.02000000',
#   '7997.52000000',
#   '8003.34000000',
#   '0.07933300',
#   1569592799999,
#   '634.69898424',
#   5,
#   '0.06126300',
#   '490.04894148',
#   '0'],
#  [1569592800000,
#   '8060.80000000',
#   '8079.21000000',
#   '7961.67000000',
#   '8013.37000000',
#   '1.71161300',
#   1569596399999,
#   '13785.79496949',
#   26,
#   '1.59193600',
#   '12828.20548776',
#   '0'],
#  [1569596400000,
#   '7976.57000000',
#   '7987.79000000',
#   '7853.53000000',
#   '7987.79000000',
#   '2.18091000',
#   1569599999999,
#   '17305.41338434',
#   45,
#   '1.79817300',
#   '14280.84944209',
#   '0'],
#  [1569600000000,
#   '7980.92000000',
#   '8043.12000000',
#   '7950.47000000',
#   '8008.89000000',
#   '2.51445600',
#   1569603599999,
#   '20121.38931625',
#   44,
#   '2.34056900',
#   '18734.54718720',
#   '0'],
#  [1569603600000,
#   '8007.77000000',
#   '8010.10000000',
#   '8007.77000000',
#   '8010.10000000',
#   '0.02769900',
#   1569607199999,
#   '221.85639122',
#   2,
#   '0.02769900',
#   '221.85639122',
#   '0'],
#  [1569607200000,
#   '8030.01000000',
#   '8046.74000000',
#   '8030.01000000',
#   '8037.25000000',
#   '0.88055000',
#   1569610799999,
#   '7080.21434196',
#   15,
#   '0.44051300',
#   '3543.63628098',
#   '0'],
#  [1569610800000,
#   '8037.25000000',
#   '8037.25000000',
#   '8037.25000000',
#   '8037.25000000',
#   '0.00000000',
#   1569614399999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569614400000,
#   '8018.90000000',
#   '8093.09000000',
#   '8018.90000000',
#   '8054.30000000',
#   '0.31935600',
#   1569617999999,
#   '2583.21864929',
#   9,
#   '0.31599300',
#   '2556.11091839',
#   '0'],
#  [1569618000000,
#   '8082.41000000',
#   '8257.25000000',
#   '8079.02000000',
#   '8246.73000000',
#   '1.39286800',
#   1569621599999,
#   '11448.28929796',
#   28,
#   '1.30606500',
#   '10738.75060461',
#   '0'],
#  [1569621600000,
#   '8229.46000000',
#   '8232.34000000',
#   '8185.40000000',
#   '8196.01000000',
#   '0.32455700',
#   1569625199999,
#   '2669.44901259',
#   7,
#   '0.23328900',
#   '1920.21422994',
#   '0'],
#  [1569625200000,
#   '8163.80000000',
#   '8187.15000000',
#   '8163.80000000',
#   '8187.15000000',
#   '0.05768300',
#   1569628799999,
#   '472.09632040',
#   2,
#   '0.00698300',
#   '57.00781540',
#   '0'],
#  [1569628800000,
#   '8187.15000000',
#   '8205.75000000',
#   '8158.50000000',
#   '8200.51000000',
#   '2.40775300',
#   1569632399999,
#   '19722.63467745',
#   30,
#   '1.81274200',
#   '14860.93593608',
#   '0'],
#  [1569632400000,
#   '8184.75000000',
#   '8190.00000000',
#   '8163.75000000',
#   '8163.75000000',
#   '0.20853800',
#   1569635999999,
#   '1706.01990693',
#   8,
#   '0.13379500',
#   '1095.54603768',
#   '0'],
#  [1569636000000,
#   '8153.25000000',
#   '8175.67000000',
#   '8153.25000000',
#   '8158.50000000',
#   '0.99027400',
#   1569639599999,
#   '8080.79978503',
#   7,
#   '0.27972000',
#   '2286.03980277',
#   '0'],
#  [1569639600000,
#   '8158.29000000',
#   '8158.29000000',
#   '8157.79000000',
#   '8157.79000000',
#   '0.04886800',
#   1569643199999,
#   '398.66656622',
#   2,
#   '0.04886800',
#   '398.66656622',
#   '0'],
#  [1569643200000,
#   '8156.16000000',
#   '8192.93000000',
#   '8153.25000000',
#   '8192.93000000',
#   '0.78445800',
#   1569646799999,
#   '6415.50247667',
#   10,
#   '0.59275900',
#   '4852.27764306',
#   '0'],
#  [1569646800000,
#   '8169.69000000',
#   '8169.69000000',
#   '8168.33000000',
#   '8168.33000000',
#   '0.04182900',
#   1569650399999,
#   '341.71307997',
#   2,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569650400000,
#   '8168.33000000',
#   '8168.33000000',
#   '8168.33000000',
#   '8168.33000000',
#   '0.00000000',
#   1569653999999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569654000000,
#   '8188.00000000',
#   '8221.98000000',
#   '8188.00000000',
#   '8221.98000000',
#   '0.23141200',
#   1569657599999,
#   '1897.35343456',
#   10,
#   '0.22141200',
#   '1815.36403456',
#   '0'],
#  [1569657600000,
#   '8200.92000000',
#   '8221.50000000',
#   '8197.67000000',
#   '8205.75000000',
#   '4.24765500',
#   1569661199999,
#   '34881.16286864',
#   36,
#   '4.20413200',
#   '34524.05093703',
#   '0'],
#  [1569661200000,
#   '8202.08000000',
#   '8221.26000000',
#   '8202.08000000',
#   '8221.26000000',
#   '0.43022600',
#   1569664799999,
#   '3533.00578318',
#   16,
#   '0.42895400',
#   '3522.55926694',
#   '0'],
#  [1569664800000,
#   '8226.75000000',
#   '8250.00000000',
#   '8180.10000000',
#   '8186.59000000',
#   '0.74108200',
#   1569668399999,
#   '6100.50897880',
#   21,
#   '0.61722400',
#   '5086.67598738',
#   '0'],
#  [1569668400000,
#   '8180.98000000',
#   '8181.27000000',
#   '8134.08000000',
#   '8142.50000000',
#   '0.65368900',
#   1569671999999,
#   '5330.83272160',
#   19,
#   '0.54196000',
#   '4421.30630206',
#   '0'],
#  [1569672000000,
#   '8121.36000000',
#   '8146.22000000',
#   '8067.92000000',
#   '8089.24000000',
#   '1.35622200',
#   1569675599999,
#   '11001.82665450',
#   27,
#   '0.60152400',
#   '4891.57633052',
#   '0'],
#  [1569675600000,
#   '8055.17000000',
#   '8058.99000000',
#   '8055.17000000',
#   '8058.99000000',
#   '0.04195300',
#   1569679199999,
#   '338.02551695',
#   2,
#   '0.04195300',
#   '338.02551695',
#   '0'],
#  [1569679200000,
#   '8101.73000000',
#   '8103.08000000',
#   '8060.14000000',
#   '8060.14000000',
#   '0.26491700',
#   1569682799999,
#   '2138.97739020',
#   7,
#   '0.03977700',
#   '322.18203756',
#   '0'],
#  [1569682800000,
#   '8050.00000000',
#   '8069.77000000',
#   '8016.75000000',
#   '8057.95000000',
#   '1.18978400',
#   1569686399999,
#   '9556.48515386',
#   65,
#   '0.99062300',
#   '7954.20569007',
#   '0'],
#  [1569686400000,
#   '8046.47000000',
#   '8115.70000000',
#   '8043.00000000',
#   '8093.17000000',
#   '1.56396300',
#   1569689999999,
#   '12671.68034334',
#   25,
#   '1.43158500',
#   '11605.36458367',
#   '0'],
#  [1569690000000,
#   '8106.15000000',
#   '8158.10000000',
#   '8106.15000000',
#   '8158.10000000',
#   '0.70888200',
#   1569693599999,
#   '5763.39554302',
#   14,
#   '0.64866200',
#   '5275.08127600',
#   '0'],
#  [1569693600000,
#   '8145.63000000',
#   '8145.63000000',
#   '8145.63000000',
#   '8145.63000000',
#   '0.02509000',
#   1569697199999,
#   '204.37385670',
#   1,
#   '0.02509000',
#   '204.37385670',
#   '0'],
#  [1569697200000,
#   '8119.36000000',
#   '8132.83000000',
#   '8115.65000000',
#   '8127.00000000',
#   '0.45999600',
#   1569700799999,
#   '3737.60473484',
#   13,
#   '0.02000000',
#   '162.43600000',
#   '0'],
#  [1569700800000,
#   '8151.24000000',
#   '8153.52000000',
#   '8122.38000000',
#   '8152.97000000',
#   '0.36014600',
#   1569704399999,
#   '2933.99591365',
#   17,
#   '0.10739800',
#   '875.50144840',
#   '0'],
#  [1569704400000,
#   '8152.97000000',
#   '8152.97000000',
#   '8152.97000000',
#   '8152.97000000',
#   '0.00226100',
#   1569707999999,
#   '18.43386517',
#   1,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569708000000,
#   '8180.83000000',
#   '8319.86000000',
#   '8087.66000000',
#   '8193.84000000',
#   '7.24406300',
#   1569711599999,
#   '59515.75803259',
#   142,
#   '6.44345200',
#   '52978.08630816',
#   '0'],
#  [1569711600000,
#   '8153.49000000',
#   '8223.12000000',
#   '8153.49000000',
#   '8206.39000000',
#   '0.09670500',
#   1569715199999,
#   '794.87929881',
#   4,
#   '0.09190700',
#   '755.63041259',
#   '0'],
#  [1569715200000,
#   '8206.39000000',
#   '8206.39000000',
#   '8206.39000000',
#   '8206.39000000',
#   '0.00000000',
#   1569718799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569718800000,
#   '8206.39000000',
#   '8206.39000000',
#   '8206.39000000',
#   '8206.39000000',
#   '0.00000000',
#   1569722399999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569722400000,
#   '8159.65000000',
#   '8159.65000000',
#   '8159.65000000',
#   '8159.65000000',
#   '0.01706500',
#   1569725999999,
#   '139.24442725',
#   5,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569726000000,
#   '8167.83000000',
#   '8167.83000000',
#   '8152.96000000',
#   '8159.52000000',
#   '0.09877700',
#   1569729599999,
#   '805.73915951',
#   8,
#   '0.09754600',
#   '795.69636607',
#   '0'],
#  [1569729600000,
#   '8126.80000000',
#   '8145.90000000',
#   '8126.80000000',
#   '8145.90000000',
#   '0.29516900',
#   1569733199999,
#   '2403.39796275',
#   8,
#   '0.29516900',
#   '2403.39796275',
#   '0'],
#  [1569733200000,
#   '8145.90000000',
#   '8145.90000000',
#   '8145.90000000',
#   '8145.90000000',
#   '0.00000000',
#   1569736799999,
#   '0.00000000',
#   0,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569736800000,
#   '8116.84000000',
#   '8128.37000000',
#   '8101.66000000',
#   '8101.66000000',
#   '0.19763500',
#   1569740399999,
#   '1605.77464564',
#   6,
#   '0.19600500',
#   '1592.56893984',
#   '0'],
#  [1569740400000,
#   '8090.25000000',
#   '8090.25000000',
#   '8061.66000000',
#   '8078.91000000',
#   '0.73289300',
#   1569743999999,
#   '5919.19718288',
#   20,
#   '0.54337400',
#   '4387.79368163',
#   '0'],
#  [1569744000000,
#   '8107.17000000',
#   '8107.17000000',
#   '8090.25000000',
#   '8090.25000000',
#   '0.13626400',
#   1569747599999,
#   '1103.55769340',
#   3,
#   '0.06408200',
#   '519.52366794',
#   '0'],
#  [1569747600000,
#   '8084.03000000',
#   '8116.36000000',
#   '8078.88000000',
#   '8101.87000000',
#   '0.76636500',
#   1569751199999,
#   '6208.24130673',
#   21,
#   '0.76636500',
#   '6208.24130673',
#   '0'],
#  [1569751200000,
#   '8091.58000000',
#   '8091.58000000',
#   '8071.92000000',
#   '8080.30000000',
#   '0.31049400',
#   1569754799999,
#   '2508.74114348',
#   11,
#   '0.29021900',
#   '2344.78654498',
#   '0'],
#  [1569754800000,
#   '8059.83000000',
#   '8103.16000000',
#   '8059.14000000',
#   '8090.25000000',
#   '1.14599400',
#   1569758399999,
#   '9268.09402284',
#   18,
#   '1.12834900',
#   '9125.34156159',
#   '0'],
#  [1569758400000,
#   '8073.51000000',
#   '8082.69000000',
#   '7923.64000000',
#   '7982.18000000',
#   '4.51693100',
#   1569761999999,
#   '36047.73510980',
#   86,
#   '1.59257600',
#   '12756.89022192',
#   '0'],
#  [1569762000000,
#   '7978.27000000',
#   '8042.06000000',
#   '7964.84000000',
#   '7990.32000000',
#   '0.58913000',
#   1569765599999,
#   '4721.55834923',
#   18,
#   '0.48589700',
#   '3898.54814777',
#   '0'],
#  [1569765600000,
#   '7990.32000000',
#   '8018.92000000',
#   '7976.74000000',
#   '7976.74000000',
#   '0.29241800',
#   1569769199999,
#   '2341.46343628',
#   14,
#   '0.29093000',
#   '2329.59404716',
#   '0'],
#  [1569769200000,
#   '7964.66000000',
#   '7979.28000000',
#   '7911.75000000',
#   '7943.15000000',
#   '1.34641700',
#   1569772799999,
#   '10713.08562034',
#   47,
#   '1.00124200',
#   '7978.31986853',
#   '0'],
#  [1569772800000,
#   '7952.25000000',
#   '8021.00000000',
#   '7943.15000000',
#   '8017.22000000',
#   '1.54747700',
#   1569776399999,
#   '12309.01101744',
#   30,
#   '1.45515600',
#   '11569.70649255',
#   '0'],
#  [1569776400000,
#   '8009.14000000',
#   '8009.14000000',
#   '7997.28000000',
#   '7997.28000000',
#   '0.04131600',
#   1569779999999,
#   '330.87710494',
#   4,
#   '0.01422700',
#   '113.91751148',
#   '0'],
#  [1569780000000,
#   '7997.37000000',
#   '7997.37000000',
#   '7972.65000000',
#   '7977.69000000',
#   '0.28645100',
#   1569783599999,
#   '2285.41085241',
#   9,
#   '0.00000000',
#   '0.00000000',
#   '0'],
#  [1569783600000,
# ...
#   '179800.08256125',
#   '0'],
#  [1572199200000,
#   '9672.86000000',
#   '9700.00000000',
#   '9630.00000000',
#   '9654.28000000',
#   '14.50405500',
#   1572202799999,
#   '140221.44498418',
#   324,
#   '6.13246500',
#   '59318.71160384',
#   '0'],
#  [1572202800000,
#   '9654.29000000',
#   '9800.00000000',
#   '9640.00000000',
#   '9727.00000000',
#   '26.27701500',
#   1572206399999,
#   '255314.38679397',
#   473,
#   '18.52395400',
#   '180138.30026395',
#   '0'],
#  [1572206400000,
#   '9733.20000000',
#   '9762.61000000',
#   '9555.00000000',
#   '9615.62000000',
#   '59.57826400',
#   1572209999999,
#   '576997.22467661',
#   1019,
#   '14.14201500',
#   '136959.30283593',
#   '0'],
#  [1572210000000,
#   '9615.65000000',
#   '9731.25000000',
#   '9508.74000000',
#   '9628.78000000',
#   '39.52039100',
#   1572213599999,
#   '379804.65594012',
#   851,
#   '20.32270300',
#   '195538.93577107',
#   '0'],
#  [1572213600000,
#   '9630.00000000',
#   '9720.00000000',
#   '9540.84000000',
#   '9579.73000000',
#   '36.52670300',
#   1572217199999,
#   '352267.91751682',
#   822,
#   '15.87791400',
#   '153202.71362480',
#   '0'],
#  [1572217200000,
#   '9585.13000000',
#   '9602.21000000',
#   '9475.00000000',
#   '9550.78000000',
#   '41.39065600',
#   1572220799999,
#   '394896.31398717',
#   747,
#   '15.54552800',
#   '148490.77251149',
#   '0'],
#  [1572220800000,
#   '9550.78000000',
#   '9724.97000000',
#   '9550.78000000',
#   '9714.95000000',
#   '32.22778900',
#   1572224399999,
#   '310789.29605059',
#   702,
#   '20.73125100',
#   '200202.26255109',
#   '0'],
#  [1572224400000,
#   '9714.95000000',
#   '9928.09000000',
#   '9665.00000000',
#   '9757.84000000',
#   '76.50509600',
#   1572227999999,
#   '749906.62364795',
#   1886,
#   '42.05156900',
#   '412281.95144339',
#   '0'],
#  [1572228000000,
#   '9750.00000000',
#   '9797.50000000',
#   '9672.96000000',
#   '9758.03000000',
#   '35.85648900',
#   1572231599999,
#   '348832.48393966',
#   712,
#   '15.60837100',
#   '151894.04481456',
#   '0'],
#  [1572231600000,
#   '9758.03000000',
#   '9767.00000000',
#   '9615.17000000',
#   '9636.07000000',
#   '47.31631900',
#   1572235199999,
#   '458718.00075676',
#   818,
#   '15.88417900',
#   '153988.71868614',
#   '0'],
#  [1572235200000,
#   '9640.44000000',
#   '9655.00000000',
#   '9546.80000000',
#   '9631.93000000',
#   '23.01077900',
#   1572238799999,
#   '220910.79177402',
#   581,
#   '9.39320500',
#   '90128.17052921',
#   '0'],
#  [1572238800000,
#   '9642.23000000',
#   '9692.00000000',
#   '9611.41000000',
#   '9629.32000000',
#   '11.68600000',
#   1572242399999,
#   '112897.76078080',
#   390,
#   '6.60176700',
#   '63778.94190697',
#   '0'],
#  [1572242400000,
#   '9623.30000000',
#   '9623.30000000',
#   '9349.98000000',
#   '9449.95000000',
#   '41.13607700',
#   1572245999999,
#   '389572.23196759',
#   1016,
#   '17.15300100',
#   '162309.27511867',
#   '0'],
#  [1572246000000,
#   '9462.32000000',
#   '9465.56000000',
#   '9363.20000000',
#   '9447.84000000',
#   '30.20020100',
#   1572249599999,
#   '283885.46217627',
#   581,
#   '14.21508100',
#   '133697.22453912',
#   '0'],
#  [1572249600000,
#   '9446.41000000',
#   '9453.98000000',
#   '9300.01000000',
#   '9373.21000000',
#   '20.31551100',
#   1572253199999,
#   '190276.65372622',
#   405,
#   '5.71314400',
#   '53449.19304599',
#   '0'],
#  [1572253200000,
#   '9362.43000000',
#   '9433.60000000',
#   '9340.00000000',
#   '9415.00000000',
#   '19.09850700',
#   1572256799999,
#   '179421.40361877',
#   319,
#   '9.58530900',
#   '90094.66679573',
#   '0'],
#  [1572256800000,
#   '9416.60000000',
#   '9479.99000000',
#   '9362.16000000',
#   '9426.84000000',
#   '11.28641900',
#   1572260399999,
#   '106407.06408782',
#   290,
#   '6.65978100',
#   '62823.76984416',
#   '0'],
#  [1572260400000,
#   '9428.30000000',
#   '9446.65000000',
#   '9360.00000000',
#   '9420.00000000',
#   '13.99162300',
#   1572263999999,
#   '131550.23480289',
#   375,
#   '5.45787300',
#   '51335.33280872',
#   '0'],
#  [1572264000000,
#   '9420.00000000',
#   '9420.00000000',
#   '9274.32000000',
#   '9347.24000000',
#   '30.15077400',
#   1572267599999,
#   '281536.74884792',
#   692,
#   '6.91932000',
#   '64609.08937782',
#   '0'],
#  [1572267600000,
#   '9340.33000000',
#   '9431.93000000',
#   '9316.24000000',
#   '9373.37000000',
#   '14.73106400',
#   1572271199999,
#   '138196.33505815',
#   478,
#   '8.92183100',
#   '83747.26089420',
#   '0'],
#  [1572271200000,
#   '9377.40000000',
#   '9385.69000000',
#   '9317.23000000',
#   '9346.34000000',
#   '11.09283000',
#   1572274799999,
#   '103753.74123926',
#   416,
#   '4.25554000',
#   '39838.57411616',
#   '0'],
#  [1572274800000,
#   '9349.99000000',
#   '9413.97000000',
#   '9331.70000000',
#   '9394.08000000',
#   '9.56987900',
#   1572278399999,
#   '89771.46274557',
#   320,
#   '6.03988200',
#   '56668.00447207',
#   '0'],
#  [1572278400000,
#   '9401.85000000',
#   '9413.97000000',
#   '9342.66000000',
#   '9371.34000000',
#   '19.65850200',
#   1572281999999,
#   '184415.00911779',
#   409,
#   '7.42673600',
#   '69696.77130009',
#   '0'],
#  [1572282000000,
#   '9377.25000000',
#   '9385.00000000',
#   '9349.60000000',
#   '9380.00000000',
#   '8.00893000',
#   1572285599999,
#   '75010.22877934',
#   221,
#   '1.39141500',
#   '13031.50423603',
#   '0'],
#  [1572285600000,
#   '9375.42000000',
#   '9497.30000000',
#   '9370.00000000',
#   '9372.43000000',
#   '29.63065000',
#   1572289199999,
#   '279340.02134199',
#   667,
#   '12.66173000',
#   '119393.65089142',
#   '0'],
#  [1572289200000,
#   '9375.00000000',
#   '9441.17000000',
#   '9375.00000000',
#   '9423.49000000',
#   '12.58396500',
#   1572292799999,
#   '118469.81495982',
#   450,
#   '6.93464400',
#   '65279.35585982',
#   '0'],
#  [1572292800000,
#   '9432.65000000',
#   '9460.00000000',
#   '9397.13000000',
#   '9448.18000000',
#   '9.83255800',
#   1572296399999,
#   '92679.38470255',
#   325,
#   '5.89439100',
#   '55570.23773231',
#   '0'],
#  [1572296400000,
#   '9448.77000000',
#   '9498.23000000',
#   '9435.00000000',
#   '9470.80000000',
#   '12.89122600',
#   1572299999999,
#   '121986.56466065',
#   330,
#   '7.64902700',
#   '72429.15636246',
#   '0'],
#  [1572300000000,
#   '9474.86000000',
#   '9481.20000000',
#   '9424.36000000',
#   '9452.19000000',
#   '15.87896300',
#   1572303599999,
#   '150096.25688803',
#   356,
#   '7.92953000',
#   '74994.61458304',
#   '0'],
#  [1572303600000,
#   '9457.23000000',
#   '9500.00000000',
#   '9195.00000000',
#   '9224.16000000',
#   '58.99797800',
#   1572307199999,
#   '549508.58211807',
#   1624,
#   '23.09966500',
#   '215367.28358693',
#   '0'],
#  [1572307200000,
#   '9219.37000000',
#   '9302.32000000',
#   '9215.00000000',
#   '9286.54000000',
#   '10.22656500',
#   1572310799999,
#   '94756.50509067',
#   288,
#   '5.35513000',
#   '49616.62867976',
#   '0'],
#  [1572310800000,
#   '9285.61000000',
#   '9317.02000000',
#   '9250.00000000',
#   '9297.06000000',
#   '10.49904900',
#   1572314399999,
#   '97441.89473176',
#   374,
#   '7.06203000',
#   '65559.15995185',
#   '0'],
#  [1572314400000,
#   '9299.90000000',
#   '9303.00000000',
#   '9245.01000000',
#   '9267.65000000',
#   '5.14976500',
#   1572317999999,
#   '47708.83872396',
#   213,
#   '2.64719000',
#   '24527.24369955',
#   '0'],
#  [1572318000000,
#   '9267.65000000',
#   '9307.80000000',
#   '9250.30000000',
#   '9299.90000000',
#   '6.90455300',
#   1572321599999,
#   '64114.23190671',
#   169,
#   '4.14030800',
#   '38463.63697000',
#   '0'],
#  [1572321600000,
#   '9305.11000000',
#   '9464.80000000',
#   '9305.11000000',
#   '9422.44000000',
#   '35.75513700',
#   1572325199999,
#   '336435.85686207',
#   793,
#   '22.96765300',
#   '216079.61963634',
#   '0'],
#  [1572325200000,
#   '9434.23000000',
#   '9545.80000000',
#   '9370.00000000',
#   '9407.98000000',
#   '48.84705800',
#   1572328799999,
#   '462745.09999467',
#   951,
#   '16.30107400',
#   '154598.54298370',
#   '0'],
#  [1572328800000,
#   '9407.98000000',
#   '9480.00000000',
#   '9387.64000000',
#   '9439.89000000',
#   '17.12348000',
#   1572332399999,
#   '161583.88584356',
#   370,
#   '8.99528300',
#   '84900.98910139',
#   '0'],
#  [1572332400000,
#   '9457.36000000',
#   '9494.18000000',
#   '9437.81000000',
#   '9449.46000000',
#   '13.86991900',
#   1572335999999,
#   '131222.91102382',
#   245,
#   '4.47809500',
#   '42370.60177546',
#   '0'],
#  [1572336000000,
#   '9453.70000000',
#   '9472.38000000',
#   '9405.00000000',
#   '9428.00000000',
#   '15.21229300',
#   1572339599999,
#   '143304.30951110',
#   254,
#   '4.23288100',
#   '39886.73096021',
#   '0'],
#  [1572339600000,
#   '9426.04000000',
#   '9426.04000000',
#   '9366.60000000',
#   '9394.82000000',
#   '15.56964400',
#   1572343199999,
#   '146350.12330383',
#   295,
#   '2.86700000',
#   '26958.24248539',
#   '0'],
#  [1572343200000,
#   '9389.19000000',
#   '9494.80000000',
#   '9389.19000000',
#   '9455.78000000',
#   '29.17540900',
#   1572346799999,
#   '275906.68355247',
#   569,
#   '21.07343200',
#   '199274.16060823',
#   '0'],
#  [1572346800000,
#   '9459.23000000',
#   '9459.23000000',
#   '9390.00000000',
#   '9439.29000000',
#   '11.36148500',
#   1572350399999,
#   '107056.88790997',
#   365,
#   '4.89648700',
#   '46156.92509776',
#   '0'],
#  [1572350400000,
#   '9428.06000000',
#   '9470.00000000',
#   '9379.59000000',
#   '9403.47000000',
#   '10.95391000',
#   1572353999999,
#   '103165.04836462',
#   335,
#   '3.59949200',
#   '33949.49071241',
#   '0'],
#  [1572354000000,
#   '9401.00000000',
#   '9424.85000000',
#   '9290.00000000',
#   '9347.57000000',
#   '26.31504200',
#   1572357599999,
#   '245887.08060853',
#   671,
#   '9.31385500',
#   '87044.04879662',
#   '0'],
#  [1572357600000,
#   '9338.80000000',
#   '9375.00000000',
#   '9313.02000000',
#   '9368.90000000',
#   '11.58661500',
#   1572361199999,
#   '108237.93312639',
#   292,
#   '6.40420600',
#   '59858.57693191',
#   '0'],
#  [1572361200000,
#   '9368.98000000',
#   '9371.88000000',
#   '9318.05000000',
#   '9356.15000000',
#   '16.94454000',
#   1572364799999,
#   '158304.50735909',
#   578,
#   '3.38722600',
#   '31649.62157346',
#   '0'],
#  [1572364800000,
#   '9350.34000000',
#   '9370.00000000',
#   '9290.72000000',
#   '9317.62000000',
#   '25.13325600',
#   1572368399999,
#   '234251.53152369',
#   521,
#   '10.71162900',
#   '99888.62658018',
#   '0'],
#  [1572368400000,
#   '9308.99000000',
#   '9360.91000000',
#   '9285.00000000',
#   '9323.21000000',
#   '19.58813600',
#   1572371999999,
#   '182739.22980698',
#   427,
#   '10.71874000',
#   '100043.53560274',
#   '0'],
#  [1572372000000,
#   '9316.97000000',
#   '9397.58000000',
#   '9313.12000000',
#   '9362.43000000',
#   '20.09859600',
#   1572375599999,
#   '188257.67455781',
#   600,
#   '11.21267800',
#   '105014.35833890',
#   '0'],
#  [1572375600000,
#   '9364.55000000',
#   '9389.68000000',
#   '9100.01000000',
#   '9237.17000000',
#   '60.02947000',
#   1572379199999,
#   '554014.93321039',
#   1288,
#   '25.89391900',
#   '238480.59747070',
#   '0'],
#  [1572379200000,
#   '9232.22000000',
#   '9490.00000000',
#   '9227.33000000',
#   '9438.93000000',
#   '80.22207900',
#   1572382799999,
#   '754983.45577069',
#   1845,
#   '41.27967300',
#   '388199.86023372',
#   '0'],
#  [1572382800000,
#   '9438.92000000',
#   '9449.00000000',
#   '9400.00000000',
#   '9421.16000000',
#   '30.47456500',
#   1572386399999,
#   '287177.81803940',
#   443,
#   '8.56748700',
#   '80833.84064897',
#   '0'],
#  [1572386400000,
#   '9419.51000000',
#   '9463.40000000',
#   '9414.45000000',
#   '9445.00000000',
#   '42.13667800',
#   1572389999999,
#   '397960.34271624',
#   725,
#   '24.96972200',
#   '235858.05681431',
#   '0'],
#  [1572390000000,
#   '9459.87000000',
#   '9463.38000000',
#   '9409.10000000',
#   '9420.66000000',
#   '28.33940900',
#   1572393599999,
#   '267293.74094423',
#   645,
#   '9.64647700',
#   '91010.81037616',
#   '0'],
#  [1572393600000,
#   '9420.66000000',
#   '9426.31000000',
#   '9271.40000000',
#   '9362.46000000',
#   '32.67612700',
#   1572397199999,
#   '305788.31909788',
#   875,
#   '8.60331000',
#   '80450.33625881',
#   '0'],
#  [1572397200000,
#   '9362.46000000',
#   '9398.84000000',
#   '9270.00000000',
#   '9391.71000000',
#   '22.63115200',
#   1572400799999,
#   '211551.35340116',
#   569,
#   '11.83580200',
#   '110686.63857840',
#   '0'],
#  [1572400800000,
#   '9395.93000000',
#   '9403.00000000',
#   '9291.80000000',
#   '9316.14000000',
#   '13.90095400',
#   1572404399999,
#   '129935.23485037',
#   475,
#   '3.06241300',
#   '28646.97977400',
#   '0'],
#  [1572404400000,
#   '9320.13000000',
#   '9330.00000000',
#   '9265.02000000',
#   '9276.81000000',
#   '8.89116000',
#   1572407999999,
#   '82651.79417179',
#   264,
#   '3.25517700',
#   '30272.64268788',
#   '0'],
#  [1572408000000,
#   '9271.59000000',
#   '9335.02000000',
#   '9225.81000000',
#   '9253.50000000',
#   '24.82172200',
#   1572411599999,
#   '230245.44902355',
#   482,
#   '12.11734900',
#   '112522.07966551',
#   '0'],
#  [1572411600000,
#   '9251.13000000',
#   '9261.33000000',
#   '9163.47000000',
#   '9206.15000000',
#   '19.90455900',
#   1572415199999,
#   '183366.37874967',
#   361,
#   '8.73397000',
#   '80539.51785528',
#   '0'],
#  [1572415200000,
#   '9202.97000000',
#   '9248.84000000',
#   '9200.91000000',
#   '9237.56000000',
#   '13.88178300',
#   1572418799999,
#   '128122.35634130',
#   186,
#   '7.36027500',
#   '67935.86502328',
#   '0'],
#  [1572418800000,
#   '9237.19000000',
#   '9258.00000000',
#   '9163.43000000',
#   '9167.89000000',
#   '14.32479600',
#   1572422399999,
#   '132007.78877617',
#   257,
#   '5.13212900',
#   '47390.39179770',
#   '0'],
#  [1572422400000,
#   '9174.74000000',
#   '9237.04000000',
#   '9166.52000000',
#   '9198.50000000',
#   '10.58584400',
#   1572425999999,
#   '97465.36874772',
#   215,
#   '5.56527100',
#   '51247.66174620',
#   '0'],
#  [1572426000000,
#   '9206.88000000',
#   '9250.00000000',
#   '9206.88000000',
#   '9223.25000000',
#   '6.75576400',
#   1572429599999,
#   '62372.56565994',
#   146,
#   '3.30770900',
#   '30545.89929335',
#   '0'],
#  [1572429600000,
#   '9221.41000000',
#   '9228.77000000',
#   '9040.00000000',
#   '9117.80000000',
#   '41.06152300',
#   1572433199999,
#   '374579.75031246',
#   932,
#   '14.07260700',
#   '128434.48356990',
#   '0'],
#  [1572433200000,
#   '9109.50000000',
#   '9115.00000000',
#   '9026.60000000',
#   '9104.14000000',
#   '32.01674600',
#   1572436799999,
#   '290620.95507595',
#   544,
#   '10.22264600',
#   '92851.36286571',
#   '0'],
#  [1572436800000,
#   '9099.00000000',
#   '9175.00000000',
#   '9094.60000000',
#   '9131.57000000',
#   '39.56717000',
#   1572440399999,
#   '361096.02503628',
#   548,
#   '16.70443000',
#   '152397.16194999',
#   '0'],
#  [1572440400000,
#   '9135.95000000',
#   '9142.51000000',
#   '9046.55000000',
#   '9052.60000000',
#   '27.97966300',
#   1572443999999,
#   '254404.58711833',
#   365,
#   '5.35795900',
#   '48712.31680514',
#   '0'],
#  [1572444000000,
#   '9045.24000000',
#   '9127.60000000',
#   '9033.40000000',
#   '9089.66000000',
#   '24.34766200',
#   1572447599999,
#   '221329.61517409',
#   440,
#   '13.27819600',
#   '120732.13044153',
#   '0'],
#  [1572447600000,
#   '9095.11000000',
#   '9117.64000000',
#   '9000.00000000',
#   '9106.54000000',
#   '41.24581200',
#   1572451199999,
#   '373562.95865823',
#   742,
#   '19.71553700',
#   '178795.16213860',
#   '0'],
#  [1572451200000,
#   '9094.17000000',
#   '9158.16000000',
#   '9019.50000000',
#   '9055.00000000',
#   '28.65424200',
#   1572454799999,
#   '259933.71367747',
#   589,
#   '12.26206300',
#   '111461.83293044',
#   '0'],
#  [1572454800000,
#   '9064.21000000',
#   '9131.00000000',
#   '9059.55000000',
#   '9107.40000000',
#   '10.60625700',
#   1572458399999,
#   '96481.67732535',
#   351,
#   '6.16153500',
#   '56045.10694431',
#   '0'],
#  [1572458400000,
#   '9108.80000000',
#   '9162.79000000',
#   '9108.80000000',
#   '9157.63000000',
#   '8.99838600',
#   1572461999999,
#   '82176.73303258',
#   241,
#   '6.70215700',
#   '61235.34196313',
#   '0'],
#  [1572462000000,
#   '9161.54000000',
#   '9204.62000000',
#   '9151.59000000',
#   '9204.62000000',
#   '11.67726300',
#   1572465599999,
#   '107155.36554920',
#   349,
#   '6.35787700',
#   '58381.20619923',
#   '0'],
#  [1572465600000,
#   '9205.00000000',
#   '9219.96000000',
#   '9145.55000000',
#   '9175.00000000',
#   '20.85023200',
#   1572469199999,
#   '191699.39800420',
#   290,
#   '10.23630400',
#   '94211.02849594',
#   '0'],
#  [1572469200000,
#   '9173.53000000',
#   '9173.53000000',
#   '9135.29000000',
#   '9139.56000000',
#   '5.82716700',
#   1572472799999,
#   '53326.71746781',
#   163,
#   '1.67030200',
#   '15287.15886372',
#   '0'],
#  [1572472800000,
#   '9139.56000000',
#   '9224.64000000',
#   '9139.56000000',
#   '9215.86000000',
#   '12.80449300',
#   1572476399999,
#   '117689.43744210',
#   330,
#   '8.11886200',
#   '74609.78030459',
#   '0'],
#  [1572476400000,
#   '9220.58000000',
#   '9223.64000000',
#   '9155.44000000',
#   '9155.44000000',
#   '12.36410100',
#   1572479999999,
#   '113486.30525083',
#   301,
#   '4.00982800',
#   '36827.86410188',
#   '0'],
#  [1572480000000,
#   '9168.41000000',
#   '9210.88000000',
#   '9134.54000000',
#   '9144.36000000',
#   '8.50558600',
#   1572483599999,
#   '78057.73159432',
#   208,
#   '1.46121000',
#   '13436.59385908',
#   '0'],
#  [1572483600000,
#   '9142.23000000',
#   '9148.29000000',
#   '9063.73000000',
#   '9069.19000000',
#   '15.97072600',
#   1572487199999,
#   '145194.78880635',
#   366,
#   '4.13573500',
#   '37591.69198366',
#   '0'],
#  ...]

# %%
len(spot_data)
# Out:
# 24134

# %%
spot_df = pd.DataFrame(spot_data)
spot_df.columns = ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
spot_df.drop(columns=['close_time', 'ignore'], inplace=True)
spot_df = spot_df.astype(type_dict)
spot_df.drop_duplicates(inplace=True)

if (spot_df["open_time"] - spot_df["open_time"].shift(1) != 3600000).sum() == 1:
    print("Data is consistent, the dataframe is saved succesfully!")
    spot_df.to_csv(save_future_data_path)
else:
    print("Data not consistent, needs to recheck manually!")
# Out:
# Data not consistent, needs to recheck manually!

# %% [markdown]
# **Manually check**

# %%
timestamp_df = pd.DataFrame(np.arange(spot_df.loc[0,"open_time"], spot_df.loc[spot_df.shape[0]-1,"open_time"]+3600000,3600000))
timestamp_df.columns = ["open_time"]
spot_df = timestamp_df.merge(spot_df, on="open_time", how="left")
spot_df.ffill(inplace=True)

# %%
spot_df.isna().sum()
# Out:
# open_time                       0
# open                            0
# high                            0
# low                             0
# close                           0
# volume                          0
# quote_asset_volume              0
# number_of_trades                0
# taker_buy_base_asset_volume     0
# taker_buy_quote_asset_volume    0
# dtype: int64

# %%
if (spot_df["open_time"] - spot_df["open_time"].shift(1) != 3600000).sum() == 1:
    print("Data is consistent, the dataframe is saved succesfully!")
    spot_df.to_csv(save_spot_data_path)
else:
    print("Data not consistent, needs to recheck manually!")
# Out:
# Data is consistent, the dataframe is saved succesfully!

# %%
steps = 1800 # Timestamp steps to be shown in the ploting figure

sns.set()

fig = plt.figure(figsize=(16,9), dpi=90)
ax = fig.add_subplot(111)

ax.plot(spot_df["close"][:spot_df.shape[0]])

ax.set_title(spot_token_pair, fontsize=20)

ax.set_xticks(range(0,spot_df.shape[0],steps),spot_df['open_time'][:spot_df.shape[0]].loc[::steps],rotation=30)

ax.set_xlabel("Time")
ax.set_ylabel("Price (USDT)")

plt.show()

# %% [markdown]
# ## Correlation between spot data and future data

# %%
temp_df = spot_df.copy()
temp_perp_df = perp_df.copy()
temp_perp_df.columns = ['perp_' + c for c in temp_perp_df.columns]
temp_perp_df.rename(columns = {
    'perp_open_time': 'open_time'
}, inplace=True)
temp_df = temp_df.merge(temp_perp_df, on='open_time', how='inner')
temp_df.corr()
# Out:
#                                    open_time      open      high       low  \
# open_time                           1.000000 -0.319307 -0.324268 -0.313917
# open                               -0.319307  1.000000  0.999643  0.999492
# high                               -0.324268  0.999643  1.000000  0.999247
# low                                -0.313917  0.999492  0.999247  1.000000
# close                              -0.319698  0.999334  0.999650  0.999582
# volume                              0.002575 -0.313060 -0.302118 -0.329489
# quote_asset_volume                 -0.149872 -0.018728 -0.006064 -0.038096
# number_of_trades                   -0.208356 -0.040357 -0.027362 -0.059511
# taker_buy_base_asset_volume         0.000394 -0.317622 -0.305188 -0.332205
# taker_buy_quote_asset_volume       -0.152414 -0.024250 -0.009781 -0.041317
# perp_open                          -0.320588  0.999993  0.999646  0.999478
# perp_high                          -0.325716  0.999560  0.999949  0.999156
# perp_low                           -0.314918  0.999389  0.999147  0.999944
# perp_close                         -0.320920  0.999331  0.999654  0.999570
# perp_volume                         0.497144 -0.315377 -0.311802 -0.320167
# perp_quote_asset_volume             0.502725 -0.117720 -0.113274 -0.123996
# perp_number_of_trades               0.561463 -0.212032 -0.207655 -0.218132
# perp_taker_buy_base_asset_volume    0.496105 -0.317991 -0.313996 -0.322257
# perp_taker_buy_quote_asset_volume   0.504420 -0.123085 -0.118082 -0.128685
#
#                                       close    volume  quote_asset_volume  \
# open_time                         -0.319698  0.002575           -0.149872
# open                               0.999334 -0.313060           -0.018728
# high                               0.999650 -0.302118           -0.006064
# low                                0.999582 -0.329489           -0.038096
# close                              1.000000 -0.315032           -0.021013
# volume                            -0.315032  1.000000            0.913394
# quote_asset_volume                -0.021013  0.913394            1.000000
# number_of_trades                  -0.042450  0.890451            0.941970
# taker_buy_base_asset_volume       -0.316879  0.989981            0.902880
# taker_buy_quote_asset_volume      -0.023209  0.901244            0.986401
# perp_open                          0.999328 -0.312565           -0.018241
# perp_high                          0.999582 -0.301138           -0.005010
# perp_low                           0.999499 -0.329927           -0.038761
# perp_close                         0.999994 -0.314520           -0.020508
# perp_volume                       -0.316073  0.634084            0.437539
# perp_quote_asset_volume           -0.118484  0.545424            0.471068
# perp_number_of_trades             -0.212842  0.563037            0.450326
# perp_taker_buy_base_asset_volume  -0.317920  0.632098            0.433585
# perp_taker_buy_quote_asset_volume -0.122853  0.545251            0.467630
#
#                                    number_of_trades  \
# open_time                                 -0.208356
# open                                      -0.040357
# high                                      -0.027362
# low                                       -0.059511
# close                                     -0.042450
# volume                                     0.890451
# quote_asset_volume                         0.941970
# number_of_trades                           1.000000
# taker_buy_base_asset_volume                0.883052
# taker_buy_quote_asset_volume               0.931722
# perp_open                                 -0.039730
# perp_high                                 -0.026170
# perp_low                                  -0.059963
# perp_close                                -0.041805
# perp_volume                                0.470319
# perp_quote_asset_volume                    0.467177
# perp_number_of_trades                      0.451437
# perp_taker_buy_base_asset_volume           0.467668
# perp_taker_buy_quote_asset_volume          0.464910
#
#                                    taker_buy_base_asset_volume  \
# open_time                                             0.000394
# open                                                 -0.317622
# high                                                 -0.305188
# low                                                  -0.332205
# close                                                -0.316879
# volume                                                0.989981
# quote_asset_volume                                    0.902880
# number_of_trades                                      0.883052
# taker_buy_base_asset_volume                           1.000000
# taker_buy_quote_asset_volume                          0.913217
# perp_open                                            -0.317122
# perp_high                                            -0.304138
# perp_low                                             -0.332551
# perp_close                                           -0.316357
# perp_volume                                           0.627980
# perp_quote_asset_volume                               0.537772
# perp_number_of_trades                                 0.555033
# perp_taker_buy_base_asset_volume                      0.629030
# perp_taker_buy_quote_asset_volume                     0.541057
#
#                                    taker_buy_quote_asset_volume  perp_open  \
# open_time                                             -0.152414  -0.320588
# open                                                  -0.024250   0.999993
# high                                                  -0.009781   0.999646
# low                                                   -0.041317   0.999478
# close                                                 -0.023209   0.999328
# volume                                                 0.901244  -0.312565
# quote_asset_volume                                     0.986401  -0.018241
# number_of_trades                                       0.931722  -0.039730
# taker_buy_base_asset_volume                            0.913217  -0.317122
# taker_buy_quote_asset_volume                           1.000000  -0.023757
# perp_open                                             -0.023757   1.000000
# perp_high                                             -0.008646   0.999572
# perp_low                                              -0.041871   0.999385
# perp_close                                            -0.022694   0.999333
# perp_volume                                            0.430150  -0.315476
# perp_quote_asset_volume                                0.461674  -0.118245
# perp_number_of_trades                                  0.440788  -0.212691
# perp_taker_buy_base_asset_volume                       0.429267  -0.318089
# perp_taker_buy_quote_asset_volume                      0.462082  -0.123614
#
#                                    perp_high  perp_low  perp_close  \
# open_time                          -0.325716 -0.314918   -0.320920
# open                                0.999560  0.999389    0.999331
# high                                0.999949  0.999147    0.999654
# low                                 0.999156  0.999944    0.999570
# close                               0.999582  0.999499    0.999994
# volume                             -0.301138 -0.329927   -0.314520
# quote_asset_volume                 -0.005010 -0.038761   -0.020508
# number_of_trades                   -0.026170 -0.059963   -0.041805
# taker_buy_base_asset_volume        -0.304138 -0.332551   -0.316357
# taker_buy_quote_asset_volume       -0.008646 -0.041871   -0.022694
# perp_open                           0.999572  0.999385    0.999333
# perp_high                           1.000000  0.999064    0.999597
# perp_low                            0.999064  1.000000    0.999497
# perp_close                          0.999597  0.999497    1.000000
# perp_volume                        -0.311664 -0.320533   -0.316151
# perp_quote_asset_volume            -0.113438 -0.124898   -0.118966
# perp_number_of_trades              -0.207986 -0.219092   -0.213458
# perp_taker_buy_base_asset_volume   -0.313829 -0.322592   -0.317997
# perp_taker_buy_quote_asset_volume  -0.118210 -0.129544   -0.123336
#
#                                    perp_volume  perp_quote_asset_volume  \
# open_time                             0.497144                 0.502725
# open                                 -0.315377                -0.117720
# high                                 -0.311802                -0.113274
# low                                  -0.320167                -0.123996
# close                                -0.316073                -0.118484
# volume                                0.634084                 0.545424
# quote_asset_volume                    0.437539                 0.471068
# number_of_trades                      0.470319                 0.467177
# taker_buy_base_asset_volume           0.627980                 0.537772
# taker_buy_quote_asset_volume          0.430150                 0.461674
# perp_open                            -0.315476                -0.118245
# perp_high                            -0.311664                -0.113438
# perp_low                             -0.320533                -0.124898
# perp_close                           -0.316151                -0.118966
# perp_volume                           1.000000                 0.916315
# perp_quote_asset_volume               0.916315                 1.000000
# perp_number_of_trades                 0.902157                 0.946995
# perp_taker_buy_base_asset_volume      0.998660                 0.911995
# perp_taker_buy_quote_asset_volume     0.918111                 0.998242
#
#                                    perp_number_of_trades  \
# open_time                                       0.561463
# open                                           -0.212032
# high                                           -0.207655
# low                                            -0.218132
# close                                          -0.212842
# volume                                          0.563037
# quote_asset_volume                              0.450326
# number_of_trades                                0.451437
# taker_buy_base_asset_volume                     0.555033
# taker_buy_quote_asset_volume                    0.440788
# perp_open                                      -0.212691
# perp_high                                      -0.207986
# perp_low                                       -0.219092
# perp_close                                     -0.213458
# perp_volume                                     0.902157
# perp_quote_asset_volume                         0.946995
# perp_number_of_trades                           1.000000
# perp_taker_buy_base_asset_volume                0.899055
# perp_taker_buy_quote_asset_volume               0.946712
#
#                                    perp_taker_buy_base_asset_volume  \
# open_time                                                  0.496105
# open                                                      -0.317991
# high                                                      -0.313996
# low                                                       -0.322257
# close                                                     -0.317920
# volume                                                     0.632098
# quote_asset_volume                                         0.433585
# number_of_trades                                           0.467668
# taker_buy_base_asset_volume                                0.629030
# taker_buy_quote_asset_volume                               0.429267
# perp_open                                                 -0.318089
# perp_high                                                 -0.313829
# perp_low                                                  -0.322592
# perp_close                                                -0.317997
# perp_volume                                                0.998660
# perp_quote_asset_volume                                    0.911995
# perp_number_of_trades                                      0.899055
# perp_taker_buy_base_asset_volume                           1.000000
# perp_taker_buy_quote_asset_volume                          0.916709
#
#                                    perp_taker_buy_quote_asset_volume
# open_time                                                   0.504420
# open                                                       -0.123085
# high                                                       -0.118082
# low                                                        -0.128685
# close                                                      -0.122853
# volume                                                      0.545251
# quote_asset_volume                                          0.467630
# number_of_trades                                            0.464910
# taker_buy_base_asset_volume                                 0.541057
# taker_buy_quote_asset_volume                                0.462082
# perp_open                                                  -0.123614
# perp_high                                                  -0.118210
# perp_low                                                   -0.129544
# perp_close                                                 -0.123336
# perp_volume                                                 0.918111
# perp_quote_asset_volume                                     0.998242
# perp_number_of_trades                                       0.946712
# perp_taker_buy_base_asset_volume                            0.916709
# perp_taker_buy_quote_asset_volume                           1.000000

# %% [markdown]
# ### Label check between spot data and perp data

# %%
perp_df = pd.read_csv(save_future_data_path)
spot_df = pd.read_csv(save_spot_data_path)

# %%
test_perp_df = perp_df[["open_time","close", "open"]]
test_perp_df.columns=["open_time","perp_close", "perp_open"]

# %%
test_spot_df = spot_df.iloc[-perp_df.shape[0]:,:][["open_time","close","open"]]
test_spot_df.columns=["open_time", "spot_close", "spot_open"]

# %%
merge_df = test_perp_df.merge(test_spot_df, on="open_time")

# %%
merge_df["diff_perp"] = merge_df["perp_close"] - merge_df["perp_open"]
merge_df["diff_spot"] = merge_df["spot_close"] - merge_df["spot_open"]

# %%
merge_df
# Out:
#            open_time  perp_close  perp_open  spot_close  spot_open  diff_perp  \
# 0      1610434800000     36433.4    36060.5    36452.84   36026.67      372.9
# 1      1610438400000     35778.9    36453.3    35814.68   36447.10     -674.4
# 2      1610442000000     35935.4    35787.8    35970.72   35814.67      147.6
# 3      1610445600000     35061.2    35924.4    35133.40   35970.23     -863.2
# 4      1610449200000     35369.2    35138.1    35451.00   35127.34      231.1
# ...              ...         ...        ...         ...        ...        ...
# 12623  1655877600000     20078.2    20336.2    20103.50   20359.60     -258.0
# 12624  1655881200000     20063.3    20080.9    20091.60   20103.60      -17.6
# 12625  1655884800000     20199.9    20063.3    20226.20   20091.60      136.6
# 12626  1655888400000     20390.3    20202.9    20415.70   20226.40      187.4
# 12627  1655892000000     20384.2    20390.4    20410.40   20415.70       -6.2
#
#        diff_spot
# 0         426.17
# 1        -632.42
# 2         156.05
# 3        -836.83
# 4         323.66
# ...          ...
# 12623    -256.10
# 12624     -12.00
# 12625     134.60
# 12626     189.30
# 12627      -5.30
#
# [12628 rows x 7 columns]

# %%
(merge_df["diff_perp"] * merge_df["diff_spot"] >= 0).sum()
# Out:
# 12429

# %%
merge_df.shape[0]
# Out:
# 12628

# %%
print("Rate of equivalent label:", (merge_df["diff_perp"] * merge_df["diff_spot"] >= 0).sum()/merge_df.shape[0])
# Out:
# Rate of equivalent label: 0.9842413683877098
